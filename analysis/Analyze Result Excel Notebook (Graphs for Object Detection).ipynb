# %% [markdown]
# # Analyzing the Results of our (small) Dataset Excel Notebook

# %% [markdown]
# ## Analyze object detection results and the different possible categories

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt

file_path = 'C:\\Users\\Admin\\Documents\\GitHub\\Team_Project_ComputerVision\\dataset_results\\current\\result_dino_mostlikeddataset.xlsx'
df = pd.read_excel(file_path, engine='openpyxl')

all_results = df['object_detection_results'].dropna().str.split(',').sum() # split the object string
flat_results = [item.strip() for item in all_results if item.strip()]
value_counts = Counter(flat_results)

sorted_value_counts = dict(sorted(value_counts.items(), key=lambda x: x[1], reverse=True)[:30])

labels = []
counts = []

for key, count in sorted_value_counts.items():
    labels.append(key)
    counts.append(count)
    

# Plot the data
plt.figure(figsize=(15, 7))
plt.bar(labels, counts, color='skyblue')
plt.xlabel('Objects Detected')
plt.ylabel('Frequency')
plt.title('Frequency of Objects Detected')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze confidence of the text results - any patterns?

# %%
import seaborn as sns

bugfree_df = df[df['text_similarity_semantic'] > 0.5] ## small problem so far: gemini does not have 

print("Highest confidence in the dataset: " + str(bugfree_df['text_similarity_semantic'].max()))
print("Lowest Confidence in the dataset: " + str(bugfree_df['text_similarity_semantic'].min()))
print("Average confidence: " + str(bugfree_df['text_similarity_semantic'].mean()))

print()

print(df.loc[df['text_similarity_semantic'].idxmin()])

min_confidence_entries = df.nsmallest(50, 'text_similarity_semantic')
print(min_confidence_entries)


plt.figure(figsize=(10, 6))
sns.histplot(df['text_similarity_semantic'], bins=50, kde=True)

# Set labels and title
plt.xlabel('Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Confidence Values')

# Set x-axis limits and ticks
plt.xlim(0, 1.0)
plt.xticks([i/100 for i in range(50, 101, 5)])

# Show plot
plt.tight_layout()
plt.show()
# Out:
# Highest confidence in the dataset: 0.9595719973246256
# Lowest Confidence in the dataset: 0.7467192014058431
# Average confidence: 0.8962316878596943
#
# image_name                                         id_1179798263312068610_2019-10-03.jpg
# object_detection_results                                building,cloud,poster,sign,water
# aisak_description                                a flyer for the corporate energy series
# moondream_description                  The image is a promotional poster for the Corp...
# gemini_description                      This is a photo of a beach. The water is a br...
# facial_emotion                                                                       ---
# text_similarity_semantic                                                        0.746719
# text_similarity_semantic_expression                                                  low
# labels                                                                               NaN
# bounding_boxes                         [   0.077397       0.378     0.15414     0.434...
# bounding_box_confidence                0.528266, 0.43048102, 0.4021855, 0.40790132, 0...
# Name: 257, dtype: object
#                                  image_name  \
# 257   id_1179798263312068610_2019-10-03.jpg
# 5016  id_1169719775657902080_2019-09-05.jpg
# 1788  id_1164499356055232512_2019-08-22.jpg
# 8768  id_1103260400047538178_2019-03-06.jpg
# 7493  id_1148007822044684289_2019-07-07.jpg
# 8152  id_1160884456040882177_2019-08-12.jpg
# 8507  id_1103253185161056256_2019-03-06.jpg
# 5974  id_1126873319012294656_2019-05-10.jpg
# 7209  id_1192812629640790016_2019-11-08.jpg
# 8496  id_1110234505007321089_2019-03-25.jpg
# 399   id_1164653335112224768_2019-08-22.jpg
# 4279  id_1108741369915498496_2019-03-21.jpg
# 3065  id_1167454780077281281_2019-08-30.jpg
# 1810  id_1086366115528359938_2019-01-18.jpg
# 6599  id_1168276652591390721_2019-09-01.jpg
# 1308  id_1193836336769355776_2019-11-11.jpg
# 2444  id_1179737926558797824_2019-10-03.jpg
# 5625  id_1199010296888729606_2019-11-25.jpg
# 2039  id_1110544513817292800_2019-03-26.jpg
# 9401  id_1203298658873044993_2019-12-07.jpg
# 7199  id_1199255387142160384_2019-11-26.jpg
# 9099  id_1092849738293088256_2019-02-05.jpg
# 3307  id_1176968486926483457_2019-09-25.jpg
# 652   id_1094612239133429760_2019-02-10.jpg
# 4965  id_1196552753943732224_2019-11-18.jpg
# 944   id_1121729440378179584_2019-04-26.jpg
# 128   id_1189273182517248002_2019-10-29.jpg
# 711   id_1137024225116590081_2019-06-07.jpg
# 467   id_1100821446719201282_2019-02-27.jpg
# 531   id_1137496112061853696_2019-06-08.jpg
# 5156  id_1191770844894236672_2019-11-05.jpg
# 6913  id_1107666243056750593_2019-03-18.jpg
# 3259  id_1156286846751694848_2019-07-30.jpg
# 9210  id_1200388459455750146_2019-11-29.jpg
# 9618  id_1102149019193827329_2019-03-03.jpg
# 6097  id_1125027917292101632_2019-05-05.jpg
# 2558  id_1099796122913161216_2019-02-24.jpg
# 4822  id_1144714608311263232_2019-06-28.jpg
# 9639  id_1171483734882705409_2019-09-10.jpg
# 2652  id_1140172105931218944_2019-06-16.jpg
# 2483  id_1153410576506220544_2019-07-22.jpg
# 2518  id_1192063239418515456_2019-11-06.jpg
# 7370  id_1092815099432259584_2019-02-05.jpg
# 1554  id_1141660035103240192_2019-06-20.jpg
# 2479  id_1188567703172333569_2019-10-27.jpg
# 9308  id_1108596912620363776_2019-03-21.jpg
# 9051  id_1173553757524766721_2019-09-16.jpg
# 3928  id_1104658146554011650_2019-03-10.jpg
# 8651  id_1099014787873280001_2019-02-22.jpg
# 8439  id_1183774468293840899_2019-10-14.jpg
#
#                                object_detection_results  \
# 257                    building,cloud,poster,sign,water
# 5016                             poster,sign,tree plant
# 1788                                             poster
# 8768                                          flag,tree
# 7493                                                NaN
# 8152                                               sign
# 8507                                                NaN
# 5974                                               sign
# 7209                                             podium
# 8496                                             poster
# 399                                              poster
# 4279                                person,podium,plant
# 3065                        poster,glacier,mountain,map
# 1810                                               bear
# 6599                                                NaN
# 1308                                                NaN
# 2444                                               flag
# 5625                                             poster
# 2039                                     sign,sign,tree
# 9401                                        poster,sign
# 7199                                             poster
# 9099                                        poster,sign
# 3307                                      flower,poster
# 652                       mountain,person,poster,person
# 4965                            cloud,water,sign,poster
# 944                                              poster
# 128                                         glacier,map
# 711                                tree,building,person
# 467                                     podium,flag,bag
# 531                                                sign
# 5156                                              water
# 6913                                  tree,plant,poster
# 3259                 tree,tree,cloud,person,sign,poster
# 9210                                               sign
# 9618                                         person,map
# 6097                                             poster
# 2558                                             flower
# 4822                   podium,tree,poster,tree,map,book
# 9639                                           tree,map
# 2652                                                NaN
# 2483                                             poster
# 2518                             tree,mountain,building
# 7370                                             poster
# 1554                                        sign,poster
# 2479                                               sign
# 9308  person,tree,poster,cloud,bird bird,bird bird,t...
# 9051             flower,person,flower,poster,plant,tree
# 3928                                             poster
# 8651                                             poster
# 8439                        sign,microphone,person,flag
#
#                                       aisak_description  \
# 257             a flyer for the corporate energy series
# 5016  a flyer for the climate change and forestry pr...
# 1788                   environmental science and policy
# 8768  climate change implications for wildlife manag...
# 7493                   environmental science and policy
# 8152               a flyer for the youth energy academy
# 8507                   environmental science and policy
# 5974  a poster for a conference on building solution...
# 7209      a picture of a quote about the quality of air
# 8496              federal reserve bank of san francisco
# 399   a newspaper article about a man who is in the ...
# 4279        araff international day of forests 21 march
# 3065  climate change and land - international climat...
# 1810  climate change an interpolicle science, scienc...
# 6599         a poster for the climate change conference
# 1308  there is an agent to stop subsizing the fossil...
# 2444  re - source report introduction to corporate s...
# 5625  a poster with a quote on the topic of diets th...
# 2039  the casserodra syndrome prediction, uncertain ...
# 9401  international bumper sticker of the day of the...
# 7199  a close up of a calculator with a price of $ 1...
# 9099        a poster for the global supply chain summit
# 3307  california leads the nation in the installatio...
# 652   the hindu himalaya assessment mountains climat...
# 4965           a poster for the meeting today at 5 30pm
# 944              petitions uk government and parliament
# 128     a newspaper article about a man in a blue shirt
# 711     smiling couple in front of the capitol building
# 467   arafed view of a conference room with a large ...
# 531   a close up of a group of people with different...
# 5156  arafal workshop on environment statistics and ...
# 6913       a free enterprise solution to climate change
# 3259   a close up of a person holding a leaf in a field
# 9210  cop25 chile 2019 - the next meeting of the eur...
# 9618  someone pointing at a globe with the capt the ...
# 6097  a close up of a person holding a stick near a ...
# 2558  arafal foods emissionss calculations attawn 7 ...
# 4822  canadian climate fund for the private sector i...
# 9639          a flyer for the climate change conference
# 2652  araflane air france envire envire envire envir...
# 2483                          podcasts in the classroom
# 2518   arafal tour of the world's most famous landmarks
# 7370  the climate report the national climate assess...
# 1554  newspaper article about the importance of the ...
# 2479  a close up of a cell phone with a text descrip...
# 9308  a poster for the international day of forests ...
# 9051  newspaper article about the daily hampshire ga...
# 3928  a poster for the european union's eudaathtion ...
# 8651  a close up of a person holding a gas pump with...
# 8439  arafed man in a jacket and tie standing at a p...
#
#                                   moondream_description  \
# 257   The image is a promotional poster for the Corp...
# 5016  The image presents a vibrant green poster with...
# 1788  The image presents the cover of a book titled ...
# 8768  The image is a promotional poster for the even...
# 7493  The image presents the cover of a book titled ...
# 8152  The image is a vibrant poster for a Youth Ener...
# 8507  The image presents the cover of a book titled ...
# 5974  The image presents a cityscape with a prominen...
# 7209  The image presents a vibrant scene of a wind f...
# 8496  The image features the logo of the Federal Res...
# 399   The image shows a text-based news article titl...
# 4279  The image depicts a woman wearing a vibrant pu...
# 3065  The image is a cover of a book titled "Climate...
# 1810  The image presents the cover of a book titled ...
# 6599  The image is a vibrant poster for the "How to ...
# 1308  The image shows a large white smokestack with ...
# 2444  The image is a promotional poster for the RE-S...
# 5625  The image presents a scientific study on the i...
# 2039  The image is a vibrant graphic design featurin...
# 9401  The image features a blue banner with white te...
# 7199  The image presents a detailed electricity bill...
# 9099  The image is a promotional poster for the CDP ...
# 3307  The image presents a vibrant graphic design ce...
# 652   The image presents a book cover titled "The Hi...
# 4965  The image presents a cityscape viewed from a h...
# 944   The image features a vibrant green banner with...
# 128   The image is a news article titled "Rising Sea...
# 711   In the image, a man and a woman are standing o...
# 467   The image depicts a conference room filled wit...
# 531   The image presents a collage of six distinct f...
# 5156  The image presents a coastal scene with a deep...
# 6913  The image is a promotional poster for the Grea...
# 3259  The image shows a man standing in a field, wea...
# 9210  The image presents two logos for the COP25 Chi...
# 9618  The image shows a close-up view of a person's ...
# 6097  The image is a poster for the film "Hannah und...
# 2558  The image presents a black and white cow stand...
# 4822  The image presents a vibrant scene set against...
# 9639  The image presents a vibrant infographic title...
# 2652  The image shows a white Air France airplane so...
# 2483  The image features a logo for a podcast called...
# 2518  The image is a vibrant advertisement for Bahri...
# 7370  The image presents the cover of a book titled ...
# 1554  The image is a newspaper article featuring a g...
# 2479  The image is a screenshot of the BBC iPlayer a...
# 9308  The image is a vibrant poster for the Internat...
# 9051  The image is a newspaper clipping from the Dai...
# 3928  The image features the logo of the European Pa...
# 8651  The image presents a table comparing the avera...
# 8439  A man stands behind a podium, delivering a spe...
#
#                                      gemini_description facial_emotion  \
# 257    This is a photo of a beach. The water is a br...            ---
# 5016   The image is a photo of a forest. The photo i...            ---
# 1788   This is the cover of a book titled "Environme...            ---
# 8768   The image is a photo of a green sea turtle sw...            ---
# 7493   This is the cover of a journal called "Enviro...            ---
# 8152   The image is a poster for an event called the...          happy
# 8507   This is the cover of a book titled "Environme...            ---
# 5974   The image is a photo of a city with many buil...            ---
# 7209                                                NaN            ---
# 8496   The image is a logo of the Federal Reserve Ba...            ---
# 399    The image is a photo of a forest fire. The fi...            ---
# 4279   The image is a photo of a smiling woman carry...          happy
# 3065   The image is a photo of a dry, cracked earth ...            ---
# 1810   The image is a photo of a polar bear walking ...            ---
# 6599   The image is a photo of a forest. The forest ...            ---
# 1308                                                NaN            ---
# 2444   The image is a promotional banner for an even...            ---
# 5625   The image is a photo of a lush green forest. ...            ---
# 2039   The image is a photo of a book cover. The boo...            ---
# 9401   The image is a photo of a bumper sticker. The...            ---
# 7199   The image is of an electricity bill. The back...            ---
# 9099   This is a digital image with a blue backgroun...            ---
# 3307   The image is a diagram showing the state of C...            ---
# 652    The image is a book cover. The cover has a bl...          happy
# 4965   The image is a photo of Honolulu, Hawaii, tak...            ---
# 944    The image is a green banner with white text t...            ---
# 128    The image shows a map of Bangkok, Thailand. T...            ---
# 711    This is a photo of two people standing in fro...          happy
# 467    This is a photo of a city council meeting. Th...       surprise
# 531    There are 6 headshots of women on a white bac...        disgust
# 5156   The image is a photo of a bay with a beach an...            ---
# 6913   The image is a photo of a man holding a globe...          happy
# 3259   The image is a photo of a young man standing ...          happy
# 9210   The image is a photo of two logos. The logos ...            ---
# 9618   The image is a photo of a hand holding a glob...        disgust
# 6097   The image is a photo of two children, a boy a...            ---
# 2558   This is an infographic image. It shows a blac...            ---
# 4822   This is a cartoon image. The image shows a gr...       surprise
# 9639   The image is a diagram that shows the Spanish...            ---
# 2652   The image shows a white airplane with the wor...            ---
# 2483   The image is a logo. It has a black circle wi...            ---
# 2518   This is a photo of an advertisement for Bahri...            ---
# 7370   The image is a cover of a book titled "The Cl...            ---
# 1554   The image shows five people in a classroom. T...           fear
# 2479                                                NaN            ---
# 9308   The image has a white background. There is a ...       surprise
# 9051   The image is a photo of a street in Holyoke, ...           fear
# 3928   The image is a poster for an event called "EU...            ---
# 8651   The image is a chart that shows the carbon ta...          happy
# 8439   This is a photo of a man giving a speech outd...        disgust
#
#       text_similarity_semantic text_similarity_semantic_expression   labels  \
# 257                   0.746719                                 low      NaN
# 5016                  0.756131                                 low      NaN
# 1788                  0.758485                                 low      NaN
# 8768                  0.759744                                 low      NaN
# 7493                  0.760440                                 low      NaN
# 8152                  0.765683                                 low      NaN
# 8507                  0.768891                                 low      NaN
# 5974                  0.769109                                 low      NaN
# 7209                  0.771999                                 low      NaN
# 8496                  0.773892                                 low      NaN
# 399                   0.777375                                 low      NaN
# 4279                  0.777768                                 low      NaN
# 3065                  0.780289                                 low      NaN
# 1810                  0.780683                                 low      NaN
# 6599                  0.783417                                 low      NaN
# 1308                  0.783964                                 low      NaN
# 2444                  0.784701                                 low      NaN
# 5625                  0.785850                                 low      NaN
# 2039                  0.790630                                 low      NaN
# 9401                  0.792683                                 low      NaN
# 7199                  0.793082                                 low      NaN
# 9099                  0.793492                                 low      NaN
# 3307                  0.796032                                 low      NaN
# 652                   0.796099                                 low      NaN
# 4965                  0.797687                                 low      NaN
# 944                   0.797818                                 low      NaN
# 128                   0.798570                                 low      NaN
# 711                   0.798901                                 low      NaN
# 467                   0.800471                                 low  crowded
# 531                   0.800958                                 low  crowded
# 5156                  0.801807                                 low      NaN
# 6913                  0.802844                                 low      NaN
# 3259                  0.803470                                 low      NaN
# 9210                  0.803766                                 low      NaN
# 9618                  0.803918                                 low      NaN
# 6097                  0.804038                                 low      NaN
# 2558                  0.804564                                 low      NaN
# 4822                  0.804650                                 low  crowded
# 9639                  0.804880                                 low      NaN
# 2652                  0.804953                                 low      NaN
# 2483                  0.804983                                 low      NaN
# 2518                  0.805055                                 low      NaN
# 7370                  0.805955                                 low      NaN
# 1554                  0.805974                                 low  crowded
# 2479                  0.806504                                 low      NaN
# 9308                  0.806813                                 low      NaN
# 9051                  0.807330                                 low      NaN
# 3928                  0.807490                                 low      NaN
# 8651                  0.807491                                 low      NaN
# 8439                  0.807502                                 low      NaN
#
#                                          bounding_boxes  \
# 257   [   0.077397       0.378     0.15414     0.434...
# 5016  [    0.49964     0.50013     0.99556     0.999...
# 1788  [     0.4999     0.50017           1     0.99976]
# 8768  [    0.50021     0.10056      0.1145     0.113...
# 7493                                                NaN
# 8152  [     0.3202     0.19954     0.43815     0.09493]
# 8507                                                NaN
# 5974  [    0.19343     0.24463     0.25466     0.33551]
# 7209  [    0.90174     0.77046     0.10229     0.23894]
# 8496  [    0.49996     0.50009           1           1]
# 399   [    0.49997     0.49978     0.99151     0.99138]
# 4279  [     0.2026     0.76629     0.40191     0.429...
# 3065  [    0.50049      0.4999     0.99888     0.999...
# 1810  [    0.73032     0.68631     0.37376     0.19386]
# 6599                                                NaN
# 1308                                                NaN
# 2444  [    0.60865      0.6252    0.051838    0.099773]
# 5625  [    0.50375     0.49979     0.91656     0.99083]
# 2039  [    0.48108     0.45946      0.4427      0.31...
# 9401  [    0.49897     0.50048     0.99126     0.981...
# 7199  [    0.49935     0.49974     0.99238     0.98707]
# 9099  [    0.49943     0.49954     0.99411     0.988...
# 3307  [    0.12959      0.3761     0.03854    0.0762...
# 652   [    0.70355     0.23694     0.58671      0.34...
# 4965  [    0.73084     0.21645     0.35907    0.0995...
# 944   [    0.49916     0.49892     0.99438     0.98604]
# 128   [    0.80838     0.52771     0.35886     0.830...
# 711   [    0.20571     0.22902     0.40702      0.45...
# 467   [    0.76033     0.70673    0.079477     0.254...
# 531   [    0.23141     0.16051     0.26193     0.31756]
# 5156  [    0.56858     0.79036     0.85742     0.40545]
# 6913  [    0.35863     0.13925    0.064187     0.129...
# 3259  [    0.10585      0.3204    0.091659     0.309...
# 9210  [    0.52909     0.74393     0.53841     0.30428]
# 9618  [    0.73183     0.63621      0.5308     0.721...
# 6097  [    0.49995     0.50044           1           1]
# 2558  [    0.33487     0.57804    0.053442    0.047595]
# 4822  [    0.35383     0.90914    0.041515    0.0833...
# 9639  [    0.48878     0.18386    0.078634    0.0512...
# 2652                                                NaN
# 2483  [    0.50004     0.49999           1           1]
# 2518  [    0.64433     0.54298    0.073095     0.124...
# 7370  [    0.50011     0.50002      0.9909     0.99175]
# 1554  [    0.50728     0.33275     0.41442     0.106...
# 2479  [    0.89239     0.18946      0.1453    0.061731]
# 9308  [    0.20995     0.46096    0.043539     0.130...
# 9051  [     0.3341     0.65497     0.11093     0.108...
# 3928  [    0.49902     0.49876     0.99196     0.98301]
# 8651  [    0.49973     0.49977     0.99075      0.9904]
# 8439  [    0.42967      0.8212     0.77047     0.351...
#
#                                 bounding_box_confidence
# 257   0.528266, 0.43048102, 0.4021855, 0.40790132, 0...
# 5016                  0.42491478, 0.4464492, 0.42381287
# 1788                                         0.37023976
# 8768                              0.3830959, 0.37960744
# 7493                                                NaN
# 8152                                          0.3930661
# 8507                                                NaN
# 5974                                          0.5170673
# 7209                                         0.46464837
# 8496                                         0.39502844
# 399                                           0.4322612
# 4279                    0.4887899, 0.3959842, 0.4602146
# 3065       0.4538952, 0.39456454, 0.3981567, 0.44289973
# 1810                                         0.42499685
# 6599                                                NaN
# 1308                                                NaN
# 2444                                         0.37226096
# 5625                                         0.39972112
# 2039                 0.49753302, 0.37554395, 0.42753488
# 9401                             0.42781156, 0.39086115
# 7199                                         0.41600016
# 9099                             0.40725946, 0.51470554
# 3307                               0.4104565, 0.3992826
# 652          0.4279133, 0.4178664, 0.3732022, 0.3717973
# 4965      0.4110934, 0.43239704, 0.44697088, 0.39564267
# 944                                          0.44293126
# 128                               0.46407723, 0.4588191
# 711                  0.44943067, 0.49042788, 0.37501016
# 467                   0.4410286, 0.38843334, 0.39947897
# 531                                          0.41214916
# 5156                                         0.42894852
# 6913                   0.5140385, 0.43818355, 0.3970562
# 3259  0.46959293, 0.41623998, 0.39028758, 0.45448855...
# 9210                                          0.3784755
# 9618                              0.5124654, 0.45134982
# 6097                                         0.45211074
# 2558                                         0.49113056
# 4822  0.46219042, 0.39711693, 0.37099928, 0.37936786...
# 9639                              0.42578217, 0.3796864
# 2652                                                NaN
# 2483                                         0.41636407
# 2518                   0.4809313, 0.4096953, 0.41393533
# 7370                                         0.43165442
# 1554                             0.49220762, 0.41291696
# 2479                                         0.47678387
# 9308  0.47000486, 0.4746321, 0.44137073, 0.4074324, ...
# 9051  0.45805627, 0.5043361, 0.40209407, 0.45179462,...
# 3928                                         0.42509094
# 8651                                         0.41069344
# 8439       0.6549799, 0.57255024, 0.5065228, 0.43481463

# %% [markdown]
# ## Analyzing Further - Moondream v2, Gemini and short text description

# %% [markdown]
# - the short text description tends to use irrational words like 'arafed' way too much, yet still feels useful in most cases to get a short impression over the image
# - gemini tends to give the best results from all models, not being prone to errors in most cases
# - gemini detects celebrities like donald trump, allowing filters to also filter for those
# - moondreamv2 tends to sometimes fail and repeat the same words several times - the cause of this is unknown (most likely hallucinations)

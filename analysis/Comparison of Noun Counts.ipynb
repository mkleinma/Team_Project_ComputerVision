# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel files into dataframes
df_random = pd.read_excel("C:\\Users\\Admin\\Documents\\GitHub\\Team_Project_ComputerVision\\noun_result_files\\noun_count_result_randomsubset_gemini_no_stopwords.xlsx")
df_mostliked = pd.read_excel("C:\\Users\\Admin\\Documents\\GitHub\\Team_Project_ComputerVision\\noun_result_files\\noun_count_result_mostlikedsubset_gemini_no_stopwords.xlsx")

# Multiply the counts in the mostliked dataframe by 2
df_mostliked['count'] *= 2

# Merge the two dataframes on the noun column
df_merged = pd.merge(df_random, df_mostliked, on='noun', suffixes=('_random', '_mostliked'))

# Calculate the absolute percentage difference between the two counts
df_filtered = df_merged[(df_merged['count_random'] > 100) & (df_merged['count_mostliked'] > 100)] a c
df_filtered['percentage_increase'] = (df_filtered['count_mostliked'] - df_filtered['count_random']) / df_filtered['count_random'] * 100

#df_filtered['abs_percentage_diff'] = abs(df_merged['count_random'] - df_merged['count_mostliked']) / df_merged[['count_random', 'count_mostliked']].max(axis=1) * 100

# Sort by the absolute percentage difference and select the top 20
top_20_diff = df_filtered.nlargest(50, 'percentage_increase')

# Plot the results
plt.figure(figsize=(10, 8))
plt.barh(top_20_diff['noun'], top_20_diff['percentage_increase'], color='skyblue')
plt.xlabel('Absolute Percentage Difference (%)')
plt.ylabel('Noun')
plt.title('Top 50 Nouns with the Largest Absolute Percentage Differences in Gemini')
plt.gca().invert_yaxis()  # To display the largest difference at the top
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_43704\3232203750.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['percentage_increase'] = (df_filtered['count_mostliked'] - df_filtered['count_random']) / df_filtered['count_random'] * 100

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel files into dataframes
df_random = pd.read_excel("C:\\Users\\Admin\\Documents\\GitHub\\Team_Project_ComputerVision\\noun_result_files\\noun_count_result_randomsubset_moondream_no_stopwords.xlsx")
df_mostliked = pd.read_excel("C:\\Users\\Admin\\Documents\\GitHub\\Team_Project_ComputerVision\\noun_result_files\\noun_count_result_mostlikedsubset_moondream_no_stopwords.xlsx")

# Multiply the counts in the mostliked dataframe by 2
df_mostliked['count'] *= 2

# Merge the two dataframes on the noun column
df_merged = pd.merge(df_random, df_mostliked, on='noun', suffixes=('_random', '_mostliked'))

# Calculate the absolute percentage difference between the two counts
df_filtered = df_merged[(df_merged['count_random'] > 100) & (df_merged['count_mostliked'] > 100)]
df_filtered['percentage_increase'] = (df_filtered['count_mostliked'] - df_filtered['count_random']) / df_filtered['count_random'] * 100

#df_filtered['abs_percentage_diff'] = abs(df_merged['count_random'] - df_merged['count_mostliked']) / df_merged[['count_random', 'count_mostliked']].max(axis=1) * 100

# Sort by the absolute percentage difference and select the top 20
top_20_diff = df_filtered.nlargest(50, 'percentage_increase')

# Plot the results
plt.figure(figsize=(10, 8))
plt.barh(top_20_diff['noun'], top_20_diff['percentage_increase'], color='skyblue')
plt.xlabel('Absolute Percentage Difference (%)')
plt.ylabel('Noun')
plt.title('Top 50 Nouns with the Biggest Absolute Percentage Differences')
plt.gca().invert_yaxis()  # To display the largest difference at the top
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_43704\3550991079.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['percentage_increase'] = (df_filtered['count_mostliked'] - df_filtered['count_random']) / df_filtered['count_random'] * 100

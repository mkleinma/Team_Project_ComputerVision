# %%
import h5py
import numpy as np    
import matplotlib.pyplot as plt
import pandas as pd
import os
from PIL import Image


######## Very basic access to the dataset - let's see what we are working with! #######
raw_dataset = h5py.File('C:/Users/Admin/Documents/GitHub/Team_Project_ComputerVision/datasets/climatevisions_2019.h5', 'r+')
image_directory = "C:\\Users\\User\\OneDrive\\Desktop\\ProjectCode\\Team_Project_ComputerVision-1\\Dataset_small"
contents = os.listdir(image_directory)
print(contents)

# Access the 'upper' data - we only have tweet data 
for item in raw_dataset.keys():
   continue
#  print("Items: " + item)    
    
# Access the actual subgroups with data for us - different info we can look at 
for item in raw_dataset.require_group('tweet_data').keys():
    continue
    #print(item)
# Out:
# ['id_1079890220290633729_2019-01-01.jpg', 'id_1079930976350932993_2019-01-01.jpg', 'id_1080106880805097474_2019-01-01.jpg', 'id_1080169037957599234_2019-01-01.jpg', 'id_1080199439992655872_2019-01-01.jpg', 'id_1080228300264538117_2019-01-01.jpg', 'id_1080368104008491018_2019-01-02.jpg', 'id_1080388441773346816_2019-01-02.jpg', 'id_1080523978190376960_2019-01-02.jpg', 'id_1080547022317412352_2019-01-02.jpg', 'id_1080582296053444608_2019-01-02.jpg', 'id_1080639926515974145_2019-01-03.jpg', 'id_1080842163104202752_2019-01-03.jpg', 'id_1080933766334476288_2019-01-03.jpg', 'id_1080972709725683712_2019-01-03.jpg', 'id_1081023930721284101_2019-01-04.jpg', 'id_1081028208403787776_2019-01-04.jpg', 'id_1081069234522935297_2019-01-04.jpg', 'id_1081204886992228353_2019-01-04.jpg', 'id_1081211263110258693_2019-01-04.jpg', 'id_1081262245546545152_2019-01-04.jpg', 'id_1081287520762118144_2019-01-04.jpg', 'id_1081302806617829376_2019-01-04.jpg', 'id_1081329963096293378_2019-01-04.jpg', 'id_1081406708436688896_2019-01-05.jpg', 'id_1081416521929445376_2019-01-05.jpg', 'id_1081505639619350528_2019-01-05.jpg', 'id_1081535653807095808_2019-01-05.jpg', 'id_1081536814383591424_2019-01-05.jpg', 'id_1081550972520984576_2019-01-05.jpg', 'id_1081592651353341952_2019-01-05.jpg', 'id_1081748459668062208_2019-01-06.jpg', 'id_1081820266362093568_2019-01-06.jpg', 'id_1082089620391657472_2019-01-07.jpg', 'id_1082114852766863360_2019-01-07.jpg', 'id_1082119718033453057_2019-01-07.jpg', 'id_1082271088091037697_2019-01-07.jpg', 'id_1082275663942483968_2019-01-07.jpg', 'id_1082346740886441984_2019-01-07.jpg', 'id_1082369786493968384_2019-01-07.jpg', 'id_1082488735655170049_2019-01-08.jpg', 'id_1082623163039653889_2019-01-08.jpg', 'id_1082694816402571264_2019-01-08.jpg', 'id_1082734932164669440_2019-01-08.jpg', 'id_1082814891671646209_2019-01-09.jpg', 'id_1083148125743783936_2019-01-09.jpg', 'id_1083157978562215936_2019-01-10.jpg', 'id_1083239341164421120_2019-01-10.jpg', 'id_1083351484476149760_2019-01-10.jpg', 'id_1083491815351697408_2019-01-10.jpg', 'id_1083507596097654786_2019-01-10.jpg', 'id_1083510058879799296_2019-01-10.jpg', 'id_1083530840250839040_2019-01-11.jpg', 'id_1083552848120561665_2019-01-11.jpg', 'id_1083695093259923456_2019-01-11.jpg', 'id_1083744396347006977_2019-01-11.jpg', 'id_1083767274618716160_2019-01-11.jpg', 'id_1083788045294305281_2019-01-11.jpg', 'id_1083901481311440896_2019-01-12.jpg', 'id_1083933655712509952_2019-01-12.jpg', 'id_1084087684090552320_2019-01-12.jpg', 'id_1084092107298689025_2019-01-12.jpg', 'id_1084196116860624896_2019-01-12.jpg', 'id_1084207219082555392_2019-01-12.jpg', 'id_1084842013890101248_2019-01-14.jpg', 'id_1085096292861263872_2019-01-15.jpg', 'id_1085258361497681920_2019-01-15.jpg', 'id_1085428830146310145_2019-01-16.jpg', 'id_1085489497905733633_2019-01-16.jpg', 'id_1085557043505885184_2019-01-16.jpg', 'id_1085590199327850496_2019-01-16.jpg', 'id_1085602875747622912_2019-01-16.jpg', 'id_1085603254887563264_2019-01-16.jpg', 'id_1085620261595041797_2019-01-16.jpg', 'id_1085633436713476096_2019-01-16.jpg', 'id_1085731205851553792_2019-01-17.jpg', 'id_1085733765358313473_2019-01-17.jpg', 'id_1085739875129688066_2019-01-17.jpg', 'id_1085765677879832576_2019-01-17.jpg', 'id_1085806407566290944_2019-01-17.jpg', 'id_1085851456245161984_2019-01-17.jpg', 'id_1085922964128841733_2019-01-17.jpg', 'id_1085955462368059394_2019-01-17.jpg', 'id_1085968139660214272_2019-01-17.jpg', 'id_1086011947370328066_2019-01-17.jpg', 'id_1086187467156398080_2019-01-18.jpg', 'id_1086191509538570241_2019-01-18.jpg', 'id_1086231721509564416_2019-01-18.jpg', 'id_1086294688280297473_2019-01-18.jpg', 'id_1086317258744434688_2019-01-18.jpg', 'id_1086401642029813760_2019-01-18.jpg', 'id_1086538373538361344_2019-01-19.jpg', 'id_1086548857603932160_2019-01-19.jpg', 'id_1086603442175524864_2019-01-19.jpg', 'id_1086657284263108609_2019-01-19.jpg', 'id_1086663702567374848_2019-01-19.jpg', 'id_1086694001561010182_2019-01-19.jpg', 'id_108696412336631398 ...

# %%
# Access the dataset within the group
dataset = raw_dataset['tweet_data']  ## excludes unnecessary information - only tweet_data
 
# Create a dictionary to store column data
data_dict = {}
    
# Iterate through the keys (assuming each key is a column name)
for key in dataset.keys():
     # Access the data for each column
     column_data = dataset[key][:]
        
     # Store the data in the dictionary with the column name as the key
     data_dict[key] = column_data
 
# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame(data_dict)
df.head()
# Out:
#                author_id                   created_at  edit_history_tweet_ids  \
# 0            b'24931983'  b'2019-01-01T23:59:01.000Z'  b'1080252082781855744'
# 1          b'2602968048'  b'2019-01-01T23:57:02.000Z'  b'1080251584729223173'
# 2  b'734730931848634368'  b'2019-01-01T23:55:49.000Z'  b'1080251277693595649'
# 3          b'1242955585'  b'2019-01-01T23:53:00.000Z'  b'1080250568583585792'
# 4            b'18085565'  b'2019-01-01T23:51:36.000Z'  b'1080250217524539393'
#
#                                 entities_annotations entities_cashtags  \
# 0  b'start:30, end:31, probability:0.4413, type:P...            b':NA'
# 1                                              b'NA'            b':NA'
# 2                                              b'NA'            b':NA'
# 3  b'start:52, end:78, probability:0.4544, type:O...            b':NA'
# 4  b'start:122, end:127, probability:0.7755, type...            b':NA'
#
#                                    entities_hashtags  \
# 0                                              b'NA'
# 1                                              b'NA'
# 2                                              b'NA'
# 3                                              b'NA'
# 4  b'start1:184, start2:239, start3:262, end1:196...
#
#                                    entities_mentions  \
# 0                                              b'NA'
# 1                                              b'NA'
# 2                                              b'NA'
# 3  b'start1:82, start2:99, end1:95, end2:109, use...
# 4  b'start1:248, start2:275, end1:261, end2:283, ...
#
#                                        entities_urls geo_coord_data  \
# 0  b'start1:66, start2:90, end1:89, end2:113, url...          b'NA'
# 1  b'start:278, end:301, url:https://t.co/is0NHYP...          b'NA'
# 2  b'start1:55, start2:260, end1:78, end2:283, ur...          b'NA'
# 3  b'start1:140, start2:164, end1:163, end2:187, ...          b'NA'
# 4  b'start:284, end:307, url:https://t.co/jqCU6Ds...          b'NA'
#
#   geo_coord_type  ... possibly_sensitive quote_count referenced_tweets  \
# 0          b'NA'  ...               True           0             b'NA'
# 1          b'NA'  ...               True           0             b'NA'
# 2          b'NA'  ...               True           0             b'NA'
# 3          b'NA'  ...               True           0             b'NA'
# 4          b'NA'  ...               True           0             b'NA'
#
#   reply_count retweet_count                 source  \
# 0           0             0          b'CoSchedule'
# 1           0             0  b'Twitter Web Client'
# 2           0             0    b'Twitter for iPad'
# 3           0             0           b'TweetDeck'
# 4           0             0  b'Twitter Web Client'
#
#                                                 text                tweet_id  \
# 0  b'Kids Win the Right to Sue the US Government ...  b'1080252082781855744'
# 1  b'Wat zou de eenvoudigste verklaring zijn dat ...  b'1080251584729223173'
# 2  b"Here's what's on the radar for climate chang...  b'1080251277693595649'
# 3  b'The biggest story of the year, for all of hu...  b'1080250568583585792'
# 4  b'Still celebrating 2016 w stale Crystal & ran...  b'1080250217524539393'
#
#    withheld_copyright withheld_countrycode
# 0               b'NA'                b'NA'
# 1               b'NA'                b'NA'
# 2               b'NA'                b'NA'
# 3               b'NA'                b'NA'
# 4               b'NA'                b'NA'
#
# [5 rows x 27 columns]

# %% [markdown]
# # Preprocessing

# %%
# strip of "b'" of all strings

cols_to_strip = [
        'author_id', 'created_at', 'edit_history_tweet_ids', 'entities_annotations', 
        'entities_hashtags', 'entities_mentions', 'entities_urls', 'geo_coord_data',
        'geo_coord_type', 'geo_placeid', 'img_name', 'img_size', 'in_reply_to_user_id',
        'lang', 'media_keys', 'referenced_tweets', 'source', 'text', 'tweet_id', 
        'withheld_copyright', 'withheld_countrycode', 'entities_cashtags'
        ]   

df[cols_to_strip] = df[cols_to_strip].astype('string')
df[cols_to_strip] = df[cols_to_strip].replace(to_replace=r'^b\':?(.*)\'$', value=r'\1', regex=True)
df['img_name'] = df['img_name'].str.rstrip('\n')


print(df.shape)
df.dtypes

# replace string NA to "real" missing value for further analysis
df = df.replace(r'^NA$', np.nan, regex=True)
df.isna().sum()


## only keep images here
# drop all columns exepct img_ columns
selected_columns = ['img_name', 'img_size']
df_selected = df.loc[:, selected_columns]
df_selected.head()
# Out:
# (714769, 27)
#                                 img_name        img_size
# 0  id_1080252082781855744_2019-01-01.jpg  (533, 1200, 3)
# 1  id_1080251584729223173_2019-01-01.jpg  (675, 1200, 3)
# 2  id_1080251277693595649_2019-01-01.jpg   (349, 620, 3)
# 3  id_1080250568583585792_2019-01-01.jpg   (348, 620, 3)
# 4  id_1080250217524539393_2019-01-01.jpg   (720, 960, 3)

# %% [markdown]
# print(df_selected['img_name'].iloc[0])
#
# Image.open

# %%
df.head()
# Out:
#             author_id                created_at edit_history_tweet_ids  \
# 0            24931983  2019-01-01T23:59:01.000Z    1080252082781855744
# 1          2602968048  2019-01-01T23:57:02.000Z    1080251584729223173
# 2  734730931848634368  2019-01-01T23:55:49.000Z    1080251277693595649
# 3          1242955585  2019-01-01T23:53:00.000Z    1080250568583585792
# 4            18085565  2019-01-01T23:51:36.000Z    1080250217524539393
#
#                                 entities_annotations entities_cashtags  \
# 0  start:30, end:31, probability:0.4413, type:Pla...               :NA
# 1                                               <NA>               :NA
# 2                                               <NA>               :NA
# 3  start:52, end:78, probability:0.4544, type:Oth...               :NA
# 4  start:122, end:127, probability:0.7755, type:P...               :NA
#
#                                    entities_hashtags  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4  start1:184, start2:239, start3:262, end1:196, ...
#
#                                    entities_mentions  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3  start1:82, start2:99, end1:95, end2:109, usern...
# 4  start1:248, start2:275, end1:261, end2:283, us...
#
#                                        entities_urls geo_coord_data  \
# 0  start1:66, start2:90, end1:89, end2:113, url1:...           <NA>
# 1  start:278, end:301, url:https://t.co/is0NHYP90...           <NA>
# 2  start1:55, start2:260, end1:78, end2:283, url1...           <NA>
# 3  start1:140, start2:164, end1:163, end2:187, ur...           <NA>
# 4  start:284, end:307, url:https://t.co/jqCU6Ds5l...           <NA>
#
#   geo_coord_type  ... possibly_sensitive quote_count referenced_tweets  \
# 0           <NA>  ...               True           0              <NA>
# 1           <NA>  ...               True           0              <NA>
# 2           <NA>  ...               True           0              <NA>
# 3           <NA>  ...               True           0              <NA>
# 4           <NA>  ...               True           0              <NA>
#
#   reply_count retweet_count              source  \
# 0           0             0          CoSchedule
# 1           0             0  Twitter Web Client
# 2           0             0    Twitter for iPad
# 3           0             0           TweetDeck
# 4           0             0  Twitter Web Client
#
#                                                 text             tweet_id  \
# 0  Kids Win the Right to Sue the US Government Ov...  1080252082781855744
# 1  Wat zou de eenvoudigste verklaring zijn dat er...  1080251584729223173
# 2  Here's what's on the radar for climate change ...  1080251277693595649
# 3  The biggest story of the year, for all of huma...  1080250568583585792
# 4  Still celebrating 2016 w stale Crystal & ranci...  1080250217524539393
#
#    withheld_copyright withheld_countrycode
# 0                <NA>                 <NA>
# 1                <NA>                 <NA>
# 2                <NA>                 <NA>
# 3                <NA>                 <NA>
# 4                <NA>                 <NA>
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#           like_count    quote_count    reply_count  retweet_count
# count  714769.000000  714769.000000  714769.000000  714769.000000
# mean       10.137216       0.441205       0.759852       3.915581
# std       259.864707      14.017944      28.498886     131.400644
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         5.000000       0.000000       0.000000       2.000000
# max     82582.000000    5007.000000   17280.000000   51781.000000

# %% [markdown]
# ## Missing Values
#
# #### Observations:
# - entities_cashtags, in_reply_to_user_id, referenced_tweets only missing values
# - 100-400 missing values: geo_coord_data, geo_coord_type, withheld_copyright, withheld_countrycode
# - around 300.000 missing: entities_annotations, entities_mentions

# %%
# replace string NA to "real" missing value for further analysis
df = df.replace(r'^NA$', np.nan, regex=True)
df.isna().sum()
# Out:
# author_id                      0
# created_at                     0
# edit_history_tweet_ids         0
# entities_annotations      424162
# entities_cashtags              2
# entities_hashtags         242003
# entities_mentions         488033
# entities_urls                  0
# geo_coord_data            551306
# geo_coord_type            714351
# geo_placeid               691120
# img_name                       0
# img_size                       0
# in_reply_to_user_id       714769
# lang                           0
# like_count                     0
# media_keys                     0
# possibly_sensitive             0
# quote_count                    0
# referenced_tweets         714769
# reply_count                    0
# retweet_count                  0
# source                         0
# text                           0
# tweet_id                       0
# withheld_copyright        714644
# withheld_countrycode      279353
# dtype: int64

# %% [markdown]
# ## Image Access
#
# ### Goals:
# - easy access to images
# - save small dataset

# %%
# we try to find the accurate
def find_month(img_name: str):
    splitted_strings = img_name.split('-')
    count = len(splitted_strings) 
    last_two_tokens = splitted_strings[count-1].split('.')
    return last_two_tokens[0]

def get_image_directory(get_month_string, argument):
    return get_month_string.get(argument)


get_month_string = {
    "01" : "/01_January/",
    "02" : "/02_February/",
    "03" : "/03_March/",
    "04" : "/04_April/",
    "05" : "/05_May/",
    "06" : "/06_June/",
    "07" : "/07_July/",
    "08" : "/08_August/",
    "09" : "/09_September/",
    "10" : "/10_October/",
    "11" : "/11_November/",
    "12" : "/12_December/"
}

# %%
################## Subset Creation #########################

### How many is up to us, can be tried out based on result of models ###
df.sort_values(by='like_count', ascending=False)
most_liked_subset =  df.nlargest(5000, 'like_count')[['like_count', 'retweet_count', 'text', 'img_name']].copy()
most_liked_subset.shape

#### Get the top 5000 tweets based on 'like_count' ####
most_liked_subset.head(5000)


#### TODO possibly some more
for x in most_liked_subset['img_name']:
    sub_directory = get_image_directory(get_month_string, find_month(x))
    print(sub_directory)
    #complete_image_directory = image_directory + sub_directory
    #print(complete_image_directory)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /05_May/
# /12_December/
# /02_February/
# /04_April/
# None
# None
# None
# None
# None
# None
# /11_November/
# /11_November/
# /06_June/
# /03_March/
# None
# /08_August/
# /09_September/
# None
# /08_August/
# None
# None
# None
# /12_December/
# None
# None
# None
# /03_March/
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# /09_September/
# None
# /11_November/
# None
# /02_February/
# /05_May/
# None
# None
# /10_October/
# None
# None
# None
# /01_January/
# /09_September/
# None
# None
# None
# /01_January/
# /03_March/
# None
# /10_October/
# /11_November/
# None
# /09_September/
# None
# /04_April/
# /03_March/
# None
# None
# None
# None
# /02_February/
# None
# /11_November/
# /12_December/
# None
# None
# None
# /01_January/
# /10_October/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /09_September/
# /06_June/
# None
# /11_November/
# /12_December/
# None
# /02_February/
# None
# None
# None
# /11_November/
# /01_January/
# /06_June/
# None
# None
# None
# None
# /04_April/
# /12_December/
# /08_August/
# None
# /12_December/
# None
# /03_March/
# None
# None
# /12_December/
# /04_April/
# None
# None
# None
# /09_September/
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# None
# None
# /06_June/
# None
# None
# /08_August/
# /05_May/
# None
# None
# /07_July/
# None
# None
# /10_October/
# None
# None
# None
# /08_August/
# /02_February/
# None
# None
# None
# None
# None
# /02_February/
# /04_April/
# /04_April/
# None
# None
# /06_June/
# None
# None
# /05_May/
# None
# /07_July/
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# /04_April/
# /10_October/
# None
# /02_February/
# None
# None
# /02_February/
# None
# None
# /04_April/
# None
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# /07_July/
# /01_January/
# None
# /03_March/
# None
# /01_January/
# None
# /07_July/
# None
# None
# None
# /02_February/
# None
# None
# /06_June/
# None
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# /04_April/
# None
# /07_July/
# None
# None
# /02_February/
# None
# None
# None
# /02_February/
# None
# /07_July/
# None
# None
# None
# /01_January/
# None
# None
# None
# /04_April/
# /04_April/
# None
# /05_May/
# /06_June/
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# /09_September/
# None
# /01_January/
# /04_April/
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /11_November/
# None
# /08_August/
# None
# /03_March/
# None
# None
# None
# /12_December/
# /02_February/
# None
# /06_June/
# None
# /06_June/
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# /08_August/
# None
# /04_April/
# None
# /01_January/
# /11_November/
# None
# /11_November/
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# /07_July/
# /05_May/
# None
# None
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# /06_June/
# /02_February/
# None
# None
# /04_April/
# /08_August/
# None
# /08_August/
# None
# /02_February/
# None
# /04_April/
# None
# /05_May/
# /01_January/
# None
# None
# /04_April/
# None
# None
# None
# /09_September/
# None
# None
# /08_August/
# /10_October/
# None
# /05_May/
# None
# None
# /01_January/
# None
# None
# None
# /08_August/
# /09_September/
# None
# None
# /04_April/
# /03_March/
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# /08_August/
# /09_September/
# None
# None
# /10_October/
# None
# None
# None
# /02_February/
# None
# None
# None
# /07_July/
# None
# /05_May/
# /06_June/
# None
# None
# None
# None
# None
# /07_July/
# None
# /02_February/
# /10_October/
# None
# None
# None
# None
# /04_April/
# /01_January/
# None
# None
# None
# None
# None
# None
# /02_February/
# None
# None
# /03_March/
# None
# /02_February/
# /03_March/
# /04_April/
# None
# /10_October/
# None
# /09_September/
# None
# None
# /05_May/
# /11_November/
# None
# /06_June/
# /10_October/
# None
# None
# None
# None
# None
# None
# None
# /11_November/
# /01_January/
# None
# /12_December/
# /08_August/
# None
# None
# /03_March/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /04_April/
# /03_March/
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# /06_June/
# /07_July/
# None
# None
# /08_August/
# /03_March/
# None
# None
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# /07_July/
# None
# /05_May/
# None
# None
# None
# /11_November/
# /01_January/
# /03_March/
# None
# /08_August/
# None
# /10_October/
# None
# None
# /03_March/
# /09_September/
# None
# None
# /09_September/
# /12_December/
# None
# /10_October/
# None
# /08_August/
# None
# None
# None
# /10_October/
# /07_July/
# None
# /05_May/
# None
# /03_March/
# None
# None
# None
# None
# None
# /07_July/
# /10_October/
# None
# None
# /10_October/
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# None
# /06_June/
# /10_October/
# /04_April/
# None
# None
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# /04_April/
# /10_October/
# None
# None
# None
# /10_October/
# /05_May/
# None
# None
# None
# None
# /09_September/
# None
# None
# /06_June/
# None
# None
# /02_February/
# /08_August/
# None
# None
# None
# None
# None
# /07_July/
# /12_December/
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# /12_December/
# /05_May/
# None
# /11_November/
# None
# /07_July/
# /07_July/
# /08_August/
# None
# None
# None
# None
# /06_June/
# /07_July/
# None
# None
# None
# None
# /11_November/
# /01_January/
# /12_December/
# /02_February/
# None
# None
# None
# None
# None
# /05_May/
# None
# /06_June/
# None
# None
# None
# None
# None
# /05_May/
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# /12_December/
# /10_October/
# /05_May/
# /02_February/
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# /10_October/
# None
# None
# None
# None
# /10_October/
# /07_July/
# None
# /10_October/
# /12_December/
# /05_May/
# None
# /08_August/
# None
# None
# None
# /10_October/
# None
# /08_August/
# None
# None
# /08_August/
# /10_October/
# None
# /12_December/
# None
# /08_August/
# None
# /02_February/
# None
# None
# None
# /01_January/
# None
# /12_December/
# /09_September/
# /04_April/
# None
# /07_July/
# /05_May/
# /01_January/
# /09_September/
# /05_May/
# /09_September/
# None
# None
# None
# /03_March/
# /06_June/
# None
# /07_July/
# /05_May/
# None
# None
# None
# /11_November/
# /06_June/
# /06_June/
# /04_April/
# /04_April/
# None
# /10_October/
# None
# /08_August/
# None
# None
# None
# /09_September/
# None
# None
# /07_July/
# /03_March/
# None
# /10_October/
# None
# /04_April/
# None
# None
# None
# /08_August/
# None
# /10_October/
# None
# None
# None
# /01_January/
# None
# /08_August/
# None
# /12_December/
# /05_May/
# /09_September/
# /01_January/
# None
# None
# None
# None
# /05_May/
# None
# None
# /08_August/
# /07_July/
# None
# None
# None
# /08_August/
# None
# None
# /11_November/
# None
# None
# None
# /06_June/
# None
# /09_September/
# None
# None
# None
# None
# /06_June/
# None
# None
# None
# None
# None
# /12_December/
# /06_June/
# None
# None
# /11_November/
# None
# /01_January/
# None
# None
# /12_December/
# /07_July/
# /07_July/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# /11_November/
# None
# /02_February/
# /04_April/
# /12_December/
# None
# /10_October/
# None
# /11_November/
# /02_February/
# /04_April/
# None
# None
# /12_December/
# None
# /12_December/
# None
# None
# /06_June/
# /11_November/
# /03_March/
# None
# /01_January/
# None
# None
# /01_January/
# /10_October/
# /02_February/
# None
# /05_May/
# /07_July/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# /01_January/
# None
# /04_April/
# None
# None
# None
# /06_June/
# None
# None
# /02_February/
# /03_March/
# None
# None
# /08_August/
# /02_February/
# /02_February/
# None
# None
# None
# None
# /11_November/
# None
# /01_January/
# None
# None
# None
# None
# /12_December/
# None
# None
# /06_June/
# /03_March/
# None
# /03_March/
# /06_June/
# /10_October/
# None
# None
# /09_September/
# /11_November/
# /06_June/
# None
# None
# /08_August/
# None
# None
# /02_February/
# None
# None
# /02_February/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /01_January/
# /12_December/
# /05_May/
# /06_June/
# None
# None
# /12_December/
# None
# /11_November/
# /12_December/
# None
# /11_November/
# None
# None
# None
# None
# None
# /06_June/
# /01_January/
# /11_November/
# None
# /01_January/
# /12_December/
# None
# None
# /01_January/
# /01_January/
# /08_August/
# None
# /06_June/
# None
# None
# /08_August/
# None
# None
# /05_May/
# /01_January/
# None
# /02_February/
# None
# /02_February/
# None
# None
# None
# /03_March/
# /07_July/
# /12_December/
# /10_October/
# None
# None
# None
# /02_February/
# None
# /11_November/
# /10_October/
# None
# None
# /01_January/
# None
# /01_January/
# None
# None
# None
# /09_September/
# None
# None
# None
# /12_December/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# /03_March/
# /01_January/
# /06_June/
# None
# None
# None
# None
# None
# /02_February/
# None
# /02_February/
# None
# None
# /01_January/
# /02_February/
# /12_December/
# /08_August/
# None
# /09_September/
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# /03_March/
# /05_May/
# None
# /03_March/
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# None
# /01_January/
# None
# None
# None
# /02_February/
# None
# None
# None
# None
# /10_October/
# /10_October/
# /12_December/
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# /02_February/
# /10_October/
# None
# /09_September/
# /12_December/
# None
# /02_February/
# None
# /06_June/
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /11_November/
# None
# None
# /09_September/
# None
# None
# /05_May/
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# /04_April/
# None
# None
# /03_March/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# /06_June/
# None
# None
# None
# None
# /11_November/
# None
# /05_May/
# /09_September/
# None
# None
# /04_April/
# /11_November/
# /07_July/
# None
# None
# /01_January/
# None
# None
# /09_September/
# /10_October/
# None
# /01_January/
# None
# None
# /04_April/
# /03_March/
# None
# /07_July/
# /03_March/
# None
# None
# None
# None
# /03_March/
# None
# /09_September/
# /02_February/
# None
# None
# /10_October/
# None
# /06_June/
# /01_January/
# /07_July/
# /11_November/
# /07_July/
# None
# None
# None
# None
# /06_June/
# /02_February/
# None
# /02_February/
# /01_January/
# None
# /04_April/
# None
# None
# None
# /03_March/
# None
# None
# None
# /11_November/
# None
# /02_February/
# /02_February/
# None
# /05_May/
# None
# /12_December/
# None
# None
# /11_November/
# None
# None
# None
# None
# /11_November/
# /05_May/
# /01_January/
# /12_December/
# None
# /02_February/
# None
# None
# None
# /01_January/
# /02_February/
# None
# /02_February/
# None
# None
# None
# /12_December/
# /04_April/
# None
# None
# /06_June/
# None
# None
# None
# /11_November/
# None
# None
# None
# /08_August/
# /10_October/
# None
# /10_October/
# None
# None
# None
# None
# /02_February/
# None
# None
# /01_January/
# None
# /06_June/
# None
# /09_September/
# /04_April/
# /10_October/
# None
# /04_April/
# None
# None
# /01_January/
# None
# /03_March/
# None
# /11_November/
# /07_July/
# /06_June/
# None
# /10_October/
# None
# /02_February/
# None
# None
# None
# None
# /11_November/
# None
# None
# None
# /12_December/
# None
# None
# /01_January/
# /08_August/
# /07_July/
# /03_March/
# /11_November/
# None
# None
# /02_February/
# None
# /06_June/
# /06_June/
# /11_November/
# /06_June/
# None
# /05_May/
# /12_December/
# None
# /01_January/
# /01_January/
# None
# /03_March/
# None
# None
# None
# /06_June/
# /12_December/
# None
# /04_April/
# None
# None
# /01_January/
# /12_December/
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# /10_October/
# None
# None
# /05_May/
# /06_June/
# None
# None
# None
# None
# None
# /02_February/
# /03_March/
# None
# /07_July/
# None
# /08_August/
# None
# /03_March/
# None
# /03_March/
# None
# /03_March/
# None
# None
# None
# /08_August/
# None
# /07_July/
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# None
# None
# None
# /01_January/
# None
# None
# /01_January/
# None
# /12_December/
# None
# None
# /07_July/
# None
# None
# /05_May/
# /07_July/
# /09_September/
# /10_October/
# None
# /01_January/
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# None
# None
# /06_June/
# /06_June/
# /11_November/
# None
# None
# None
# /05_May/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# None
# None
# /01_January/
# None
# None
# /11_November/
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# None
# /09_September/
# None
# /09_September/
# None
# None
# None
# /02_February/
# /07_July/
# /08_August/
# /06_June/
# /04_April/
# /03_March/
# /02_February/
# /08_August/
# None
# /06_June/
# /04_April/
# /04_April/
# None
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# None
# None
# /01_January/
# None
# None
# /08_August/
# None
# None
# None
# /04_April/
# None
# None
# /06_June/
# None
# /10_October/
# /01_January/
# /05_May/
# None
# None
# None
# None
# None
# /05_May/
# /04_April/
# /05_May/
# None
# /06_June/
# None
# /11_November/
# /07_July/
# /12_December/
# None
# /02_February/
# None
# None
# /10_October/
# /11_November/
# None
# None
# None
# /05_May/
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# /02_February/
# None
# /04_April/
# /10_October/
# None
# /05_May/
# /06_June/
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# /06_June/
# None
# None
# None
# /11_November/
# None
# None
# /08_August/
# None
# /04_April/
# /08_August/
# None
# None
# /06_June/
# /10_October/
# /11_November/
# /07_July/
# None
# None
# /03_March/
# None
# None
# /09_September/
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# /11_November/
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# /04_April/
# None
# /09_September/
# None
# /06_June/
# None
# None
# /04_April/
# None
# None
# None
# /04_April/
# None
# /05_May/
# None
# None
# /05_May/
# /08_August/
# /06_June/
# None
# /02_February/
# /08_August/
# None
# None
# None
# None
# None
# /08_August/
# /03_March/
# /04_April/
# None
# None
# /12_December/
# /04_April/
# None
# /09_September/
# /02_February/
# None
# None
# /09_September/
# None
# /10_October/
# None
# None
# None
# None
# None
# /01_January/
# None
# /01_January/
# /10_October/
# /07_July/
# None
# None
# /03_March/
# /11_November/
# None
# /01_January/
# None
# /11_November/
# /12_December/
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /03_March/
# /07_July/
# /05_May/
# None
# None
# None
# None
# /12_December/
# None
# None
# /10_October/
# /10_October/
# None
# /09_September/
# None
# /01_January/
# None
# /01_January/
# None
# /01_January/
# /04_April/
# None
# /12_December/
# None
# None
# None
# /01_January/
# None
# None
# /05_May/
# None
# /05_May/
# /07_July/
# /03_March/
# None
# None
# None
# None
# None
# /09_September/
# /05_May/
# None
# None
# None
# None
# None
# /10_October/
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# None
# /06_June/
# /04_April/
# /06_June/
# /07_July/
# None
# /05_May/
# /10_October/
# None
# /12_December/
# None
# None
# None
# None
# /07_July/
# None
# None
# /10_October/
# /03_March/
# None
# /04_April/
# None
# None
# None
# None
# /08_August/
# None
# /11_November/
# /07_July/
# None
# /07_July/
# None
# /12_December/
# /05_May/
# None
# None
# None
# None
# /01_January/
# None
# /09_September/
# None
# /11_November/
# /01_January/
# /11_November/
# None
# None
# /07_July/
# /11_November/
# /01_January/
# /03_March/
# /05_May/
# None
# /05_May/
# /12_December/
# /04_April/
# /01_January/
# None
# /04_April/
# None
# None
# None
# /12_December/
# None
# None
# /12_December/
# None
# /04_April/
# None
# /02_February/
# /12_December/
# None
# None
# None
# None
# None
# /01_January/
# /05_May/
# /08_August/
# None
# /10_October/
# None
# None
# None
# None
# /10_October/
# /04_April/
# /11_November/
# None
# /07_July/
# /01_January/
# None
# None
# /10_October/
# None
# None
# /09_September/
# None
# /09_September/
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# None
# None
# /08_August/
# None
# None
# /03_March/
# /07_July/
# /02_February/
# None
# /03_March/
# None
# None
# None
# /01_January/
# /09_September/
# /10_October/
# None
# /05_May/
# /07_July/
# /02_February/
# /02_February/
# /07_July/
# None
# /03_March/
# None
# /02_February/
# /02_February/
# None
# /12_December/
# None
# /09_September/
# /06_June/
# /09_September/
# /01_January/
# None
# None
# None
# /06_June/
# /06_June/
# None
# None
# None
# /01_January/
# /02_February/
# /07_July/
# None
# None
# None
# None
# /04_April/
# None
# /06_June/
# None
# /01_January/
# None
# /03_March/
# /07_July/
# None
# None
# /11_November/
# None
# None
# /03_March/
# None
# None
# None
# /04_April/
# /09_September/
# None
# /01_January/
# None
# /02_February/
# /01_January/
# /08_August/
# None
# None
# /10_October/
# None
# /02_February/
# /09_September/
# /07_July/
# /04_April/
# None
# /10_October/
# None
# /01_January/
# /05_May/
# None
# None
# /11_November/
# None
# /11_November/
# None
# None
# /03_March/
# None
# /11_November/
# None
# None
# /02_February/
# None
# None
# /05_May/
# /02_February/
# None
# /05_May/
# None
# None
# None
# None
# None
# /10_October/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# /02_February/
# None
# /02_February/
# None
# None
# /04_April/
# /12_December/
# /01_January/
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# /08_August/
# /03_March/
# None
# /07_July/
# None
# None
# None
# None
# /11_November/
# /06_June/
# None
# None
# /01_January/
# /09_September/
# /01_January/
# /02_February/
# /01_January/
# /03_March/
# None
# /12_December/
# None
# None
# None
# None
# None
# /09_September/
# /12_December/
# None
# None
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# /04_April/
# None
# /09_September/
# None
# None
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# /11_November/
# /08_August/
# None
# /01_January/
# None
# /10_October/
# None
# None
# None
# /11_November/
# None
# None
# /03_March/
# None
# None
# /08_August/
# None
# /01_January/
# /02_February/
# None
# None
# None
# None
# None
# None
# /06_June/
# None
# None
# None
# None
# /10_October/
# None
# None
# /07_July/
# /02_February/
# None
# None
# /12_December/
# /10_October/
# None
# /03_March/
# None
# None
# None
# None
# None
# /05_May/
# /02_February/
# None
# None
# None
# /08_August/
# /06_June/
# /04_April/
# None
# None
# /04_April/
# None
# None
# /11_November/
# None
# /05_May/
# /07_July/
# None
# /07_July/
# None
# /04_April/
# None
# None
# /08_August/
# /03_March/
# None
# /04_April/
# None
# None
# None
# None
# /04_April/
# None
# /07_July/
# None
# None
# /07_July/
# None
# None
# /04_April/
# None
# /08_August/
# /02_February/
# /10_October/
# None
# None
# None
# None
# None
# /05_May/
# /05_May/
# /10_October/
# None
# None
# None
# /05_May/
# /05_May/
# None
# /02_February/
# /03_March/
# /05_May/
# None
# None
# None
# None
# /05_May/
# /08_August/
# /11_November/
# /09_September/
# None
# /07_July/
# /02_February/
# /02_February/
# None
# /08_August/
# /11_November/
# /03_March/
# None
# /07_July/
# None
# None
# None
# /08_August/
# None
# /01_January/
# /12_December/
# None
# /04_April/
# None
# None
# None
# None
# /05_May/
# None
# None
# /07_July/
# None
# /08_August/
# None
# /03_March/
# /09_September/
# None
# /01_January/
# /03_March/
# /08_August/
# None
# /10_October/
# None
# None
# None
# None
# None
# None
# /07_July/
# /08_August/
# /03_March/
# None
# None
# None
# /12_December/
# None
# /08_August/
# None
# /10_October/
# /11_November/
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# None
# /06_June/
# /09_September/
# None
# /09_September/
# /12_December/
# None
# None
# None
# /01_January/
# /03_March/
# None
# None
# /10_October/
# /07_July/
# None
# None
# None
# None
# None
# None
# /10_October/
# /06_June/
# /08_August/
# None
# None
# /05_May/
# /09_September/
# None
# /02_February/
# None
# None
# /06_June/
# None
# /09_September/
# None
# None
# /11_November/
# None
# /09_September/
# /04_April/
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# /01_January/
# None
# /12_December/
# None
# /12_December/
# None
# /02_February/
# /01_January/
# None
# None
# /03_March/
# /10_October/
# None
# /07_July/
# None
# None
# None
# None
# None
# /07_July/
# None
# /01_January/
# None
# None
# /06_June/
# None
# None
# /09_September/
# None
# /07_July/
# None
# None
# /06_June/
# None
# /08_August/
# None
# /05_May/
# /09_September/
# /03_March/
# None
# None
# None
# /10_October/
# None
# None
# /06_June/
# None
# /09_September/
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# /03_March/
# /06_June/
# /03_March/
# /10_October/
# /12_December/
# None
# None
# /02_February/
# /04_April/
# None
# None
# None
# /07_July/
# None
# /12_December/
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# /06_June/
# None
# /05_May/
# None
# None
# None
# None
# /09_September/
# None
# /11_November/
# None
# /10_October/
# /08_August/
# None
# /01_January/
# /06_June/
# /07_July/
# None
# None
# /06_June/
# /02_February/
# /09_September/
# /01_January/
# /07_July/
# None
# None
# None
# None
# None
# /09_September/
# /07_July/
# None
# None
# None
# None
# /04_April/
# None
# /01_January/
# /08_August/
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# None
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# /08_August/
# /06_June/
# /07_July/
# None
# None
# None
# /10_October/
# None
# None
# /02_February/
# /02_February/
# None
# /08_August/
# None
# /11_November/
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# /10_October/
# None
# None
# None
# /09_September/
# None
# /04_April/
# None
# /12_December/
# None
# None
# /11_November/
# None
# /11_November/
# None
# /02_February/
# /07_July/
# /10_October/
# None
# None
# /04_April/
# /03_March/
# /01_January/
# /10_October/
# None
# None
# /08_August/
# None
# None
# /03_March/
# None
# None
# /06_June/
# /07_July/
# /12_December/
# /12_December/
# None
# /12_December/
# None
# /10_October/
# None
# /10_October/
# /07_July/
# None
# /01_January/
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# /09_September/
# None
# /07_July/
# /09_September/
# None
# /12_December/
# None
# None
# None
# None
# /08_August/
# /12_December/
# None
# /01_January/
# None
# None
# /01_January/
# /02_February/
# None
# None
# None
# /06_June/
# None
# None
# None
# None
# None
# None
# None
# /09_September/
# /06_June/
# None
# /07_July/
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# /09_September/
# /08_August/
# None
# None
# None
# /02_February/
# None
# None
# None
# /04_April/
# None
# None
# None
# /10_October/
# /12_December/
# /02_February/
# /09_September/
# /04_April/
# None
# None
# /06_June/
# None
# None
# /08_August/
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# /01_January/
# /12_December/
# /01_January/
# None
# None
# /09_September/
# None
# None
# None
# /08_August/
# None
# None
# /08_August/
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# /10_October/
# None
# None
# None
# /05_May/
# None
# None
# /06_June/
# /08_August/
# None
# /06_June/
# None
# None
# None
# /09_September/
# /11_November/
# /10_October/
# /10_October/
# None
# /03_March/
# /01_January/
# None
# None
# /01_January/
# /02_February/
# None
# None
# /02_February/
# None
# None
# None
# /12_December/
# None
# None
# /01_January/
# None
# /08_August/
# None
# None
# None
# /03_March/
# /07_July/
# /04_April/
# None
# None
# None
# None
# /07_July/
# /11_November/
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# /06_June/
# /06_June/
# None
# None
# None
# None
# None
# None
# /02_February/
# /04_April/
# None
# None
# None
# /12_December/
# /12_December/
# /12_December/
# /12_December/
# None
# /03_March/
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# /02_February/
# None
# /01_January/
# None
# /09_September/
# None
# None
# /01_January/
# /12_December/
# None
# None
# None
# /12_December/
# None
# /07_July/
# None
# None
# None
# None
# None
# /10_October/
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# /01_January/
# /09_September/
# /10_October/
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# /02_February/
# None
# None
# None
# /03_March/
# /04_April/
# /09_September/
# /11_November/
# None
# None
# None
# /09_September/
# /11_November/
# None
# /08_August/
# /12_December/
# None
# /03_March/
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# /04_April/
# None
# None
# None
# None
# /11_November/
# /09_September/
# None
# /04_April/
# None
# /03_March/
# /11_November/
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# /05_May/
# /07_July/
# /10_October/
# /10_October/
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# /12_December/
# /09_September/
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# /08_August/
# None
# /11_November/
# /01_January/
# None
# None
# None
# /10_October/
# None
# None
# None
# /12_December/
# None
# None
# /02_February/
# /06_June/
# None
# None
# /02_February/
# /08_August/
# /11_November/
# /12_December/
# None
# /08_August/
# None
# None
# None
# /01_January/
# None
# /08_August/
# /12_December/
# None
# None
# /02_February/
# /10_October/
# None
# None
# /04_April/
# None
# None
# /08_August/
# None
# None
# None
# None
# /06_June/
# None
# None
# None
# /09_September/
# /08_August/
# /05_May/
# /01_January/
# /01_January/
# /04_April/
# None
# None
# /04_April/
# /11_November/
# None
# None
# None
# /12_December/
# /04_April/
# None
# None
# /12_December/
# None
# None
# None
# /07_July/
# None
# /02_February/
# /12_December/
# None
# /06_June/
# None
# /03_March/
# None
# None
# /06_June/
# None
# /06_June/
# /12_December/
# None
# /04_April/
# None
# /11_November/
# None
# /10_October/
# /05_May/
# /03_March/
# /10_October/
# /10_October/
# /03_March/
# /06_June/
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# /02_February/
# /09_September/
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# /04_April/
# /06_June/
# /06_June/
# /08_August/
# None
# /09_September/
# None
# None
# /02_February/
# None
# /01_January/
# /03_March/
# /09_September/
# /12_December/
# None
# /07_July/
# /12_December/
# None
# None
# None
# /07_July/
# /01_January/
# /09_September/
# /04_April/
# None
# /07_July/
# None
# /10_October/
# /12_December/
# /03_March/
# None
# /05_May/
# None
# None
# None
# /02_February/
# None
# None
# None
# /07_July/
# /09_September/
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# None
# None
# /11_November/
# None
# /11_November/
# None
# None
# /06_June/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# /07_July/
# None
# None
# /06_June/
# /08_August/
# None
# /12_December/
# None
# None
# None
# None
# None
# /01_January/
# /01_January/
# /12_December/
# None
# /04_April/
# None
# None
# None
# /12_December/
# None
# None
# None
# /02_February/
# None
# None
# None
# /03_March/
# /07_July/
# /06_June/
# None
# None
# None
# None
# /03_March/
# /10_October/
# None
# /11_November/
# None
# None
# None
# None
# /02_February/
# /04_April/
# /01_January/
# /07_July/
# /12_December/
# None
# /11_November/
# None
# None
# None
# None
# None
# None
# /06_June/
# None
# /06_June/
# /07_July/
# None
# /05_May/
# /08_August/
# None
# /02_February/
# /06_June/
# /11_November/
# None
# None
# None
# /10_October/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# /12_December/
# None
# /06_June/
# None
# None
# None
# /04_April/
# None
# None
# None
# /03_March/
# None
# None
# None
# /04_April/
# /04_April/
# /02_February/
# None
# None
# /03_March/
# /12_December/
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# /09_September/
# /12_December/
# None
# None
# /01_January/
# /06_June/
# /08_August/
# None
# /05_May/
# /10_October/
# None
# None
# None
# /06_June/
# None
# /10_October/
# /11_November/
# None
# /06_June/
# /11_November/
# /01_January/
# None
# /09_September/
# None
# /06_June/
# /07_July/
# None
# /01_January/
# /05_May/
# None
# None
# None
# /06_June/
# /06_June/
# None
# None
# /10_October/
# /06_June/
# /10_October/
# None
# None
# None
# /11_November/
# None
# /05_May/
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# /04_April/
# /04_April/
# /11_November/
# None
# /04_April/
# None
# None
# None
# None
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# /12_December/
# None
# /07_July/
# None
# None
# /09_September/
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# /06_June/
# /08_August/
# /06_June/
# /07_July/
# None
# None
# /05_May/
# None
# None
# /07_July/
# /05_May/
# /06_June/
# None
# None
# /04_April/
# /08_August/
# None
# None
# /05_May/
# None
# None
# /05_May/
# None
# None
# /06_June/
# None
# None
# None
# /09_September/
# /11_November/
# None
# None
# None
# /04_April/
# /06_June/
# /12_December/
# None
# None
# None
# None
# None
# /03_March/
# None
# /01_January/
# /07_July/
# None
# None
# None
# None
# None
# None
# /07_July/
# /10_October/
# None
# /01_January/
# None
# None
# None
# None
# None
# /02_February/
# /03_March/
# /05_May/
# /01_January/
# None
# /05_May/
# /08_August/
# None
# /01_January/
# None
# None
# /08_August/
# /11_November/
# None
# None
# None
# /11_November/
# None
# /03_March/
# /03_March/
# /08_August/
# None
# None
# /02_February/
# None
# /04_April/
# /11_November/
# /11_November/
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# /03_March/
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# None
# /06_June/
# /07_July/
# None
# None
# None
# None
# /02_February/
# /03_March/
# /03_March/
# /03_March/
# /05_May/
# /04_April/
# None
# /03_March/
# None
# /04_April/
# None
# None
# /12_December/
# /10_October/
# None
# None
# None
# None
# None
# None
# /06_June/
# /04_April/
# None
# None
# /07_July/
# None
# None
# /11_November/
# None
# None
# None
# None
# /08_August/
# None
# None
# None
# /09_September/
# None
# None
# None
# /02_February/
# /05_May/
# /06_June/
# None
# None
# None
# None
# None
# None
# /05_May/
# None
# /01_January/
# /02_February/
# None
# /05_May/
# None
# /11_November/
# None
# /01_January/
# /08_August/
# None
# /09_September/
# /09_September/
# None
# None
# None
# None
# None
# /03_March/
# /05_May/
# /07_July/
# /09_September/
# /10_October/
# None
# None
# None
# None
# /08_August/
# /10_October/
# /11_November/
# None
# /02_February/
# /03_March/
# /08_August/
# None
# /04_April/
# /12_December/
# None
# None
# None
# None
# /07_July/
# /07_July/
# None
# /12_December/
# None
# None
# /04_April/
# /06_June/
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# /11_November/
# /02_February/
# None
# None
# None
# /01_January/
# /08_August/
# /12_December/
# None
# /03_March/
# /03_March/
# None
# /03_March/
# None
# None
# /03_March/
# /07_July/
# None
# /04_April/
# None
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# /12_December/
# /01_January/
# /05_May/
# None
# /08_August/
# /12_December/
# None
# /06_June/
# /09_September/
# None
# None
# None
# None
# None
# None
# /04_April/
# /09_September/
# /02_February/
# /04_April/
# /05_May/
# None
# /04_April/
# /07_July/
# None
# None
# None
# /01_January/
# None
# /04_April/
# None
# None
# /01_January/
# /09_September/
# /12_December/
# None
# /08_August/
# /01_January/
# /08_August/
# /03_March/
# /09_September/
# /08_August/
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# /03_March/
# /06_June/
# None
# None
# None
# None
# /01_January/
# /02_February/
# None
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# /08_August/
# /11_November/
# /12_December/
# None
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# /07_July/
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# None
# /03_March/
# /11_November/
# None
# None
# None
# /10_October/
# None
# None
# None
# None
# None
# /01_January/
# /07_July/
# None
# None
# None
# None
# /04_April/
# None
# None
# /09_September/
# /12_December/
# None
# None
# /01_January/
# /09_September/
# None
# None
# None
# None
# /11_November/
# /12_December/
# /08_August/
# /10_October/
# /10_October/
# None
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# /07_July/
# None
# None
# None
# /01_January/
# /05_May/
# /03_March/
# None
# /05_May/
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# None
# /06_June/
# None
# None
# /03_March/
# /04_April/
# None
# None
# None
# None
# None
# /04_April/
# /07_July/
# /07_July/
# /11_November/
# None
# /11_November/
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /11_November/
# /12_December/
# None
# None
# None
# None
# /07_July/
# /08_August/
# /10_October/
# /08_August/
# /04_April/
# None
# /05_May/
# None
# None
# None
# None
# None
# /01_January/
# None
# /10_October/
# None
# None
# None
# None
# /08_August/
# None
# None
# /10_October/
# /12_December/
# None
# None
# /06_June/
# None
# None
# /01_January/
# None
# /12_December/
# /06_June/
# /05_May/
# /07_July/
# /11_November/
# /01_January/
# /03_March/
# /08_August/
# None
# /06_June/
# /05_May/
# /06_June/
# /08_August/
# None
# None
# None
# None
# /05_May/
# /06_June/
# /03_March/
# None
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /07_July/
# /09_September/
# None
# None
# /01_January/
# /09_September/
# None
# /04_April/
# /06_June/
# /07_July/
# None
# None
# None
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# /09_September/
# /08_August/
# None
# /04_April/
# /05_May/
# /06_June/
# /07_July/
# None
# None
# None
# /06_June/
# /10_October/
# None
# None
# /12_December/
# /02_February/
# /11_November/
# /09_September/
# None
# None
# /03_March/
# /05_May/
# /01_January/
# /01_January/
# /10_October/
# None
# None
# None
# /10_October/
# None
# /04_April/
# /04_April/
# None
# /09_September/
# None
# /07_July/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /11_November/
# /12_December/
# None
# None
# None
# None
# None
# None
# /02_February/
# /02_February/
# None
# None
# /02_February/
# None
# None
# None
# /11_November/
# /07_July/
# None
# /09_September/
# /06_June/
# None
# None
# /05_May/
# /07_July/
# None
# None
# /03_March/
# /11_November/
# None
# /02_February/
# None
# None
# None
# None
# None
# /03_March/
# /07_July/
# /05_May/
# /08_August/
# /11_November/
# /08_August/
# None
# /08_August/
# None
# None
# None
# /11_November/
# /06_June/
# None
# None
# None
# /11_November/
# None
# None
# None
# None
# None
# /12_December/
# /09_September/
# None
# None
# None
# None
# None
# /09_September/
# None
# /09_September/
# None
# /11_November/
# None
# None
# /03_March/
# None
# /09_September/
# None
# /02_February/
# /04_April/
# None
# None
# None
# /03_March/
# None
# /08_August/
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# /04_April/
# None
# None
# /11_November/
# /11_November/
# None
# None
# None
# None
# /08_August/
# None
# None
# /03_March/
# None
# None
# None
# None
# /08_August/
# /09_September/
# /12_December/
# None
# None
# None
# None
# None
# /06_June/
# /12_December/
# None
# /04_April/
# /07_July/
# None
# None
# None
# /08_August/
# /09_September/
# None
# None
# None
# /02_February/
# /11_November/
# None
# None
# None
# None
# None
# /03_March/
# /08_August/
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# /12_December/
# None
# /03_March/
# /08_August/
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /01_January/
# /02_February/
# None
# None
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /04_April/
# /07_July/
# /04_April/
# None
# None
# /05_May/
# None
# None
# None
# None
# /08_August/
# None
# None
# /12_December/
# /12_December/
# None
# None
# /10_October/
# None
# None
# /03_March/
# /07_July/
# /01_January/
# /06_June/
# None
# /01_January/
# /06_June/
# None
# None
# None
# None
# None
# /06_June/
# /05_May/
# /01_January/
# /10_October/
# None
# None
# /09_September/
# None
# None
# None
# /01_January/
# /03_March/
# None
# /04_April/
# None
# None
# /02_February/
# /08_August/
# None
# None
# /02_February/
# /05_May/
# /06_June/
# None
# None
# None
# None
# None
# /03_March/
# /07_July/
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# /02_February/
# /09_September/
# None
# None
# None
# /01_January/
# /07_July/
# /09_September/
# /04_April/
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /11_November/
# /11_November/
# None
# None
# /11_November/
# /03_March/
# None
# /06_June/
# None
# None
# None
# None
# /01_January/
# None
# None
# /07_July/
# None
# None
# None
# /02_February/
# None
# None
# /04_April/
# /08_August/
# None
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# None
# /11_November/
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# /01_January/
# /09_September/
# /10_October/
# None
# None
# /08_August/
# None
# /01_January/
# /06_June/
# None
# None
# None
# None
# /03_March/
# /08_August/
# None
# None
# None
# None
# /05_May/
# /06_June/
# None
# /03_March/
# /11_November/
# None
# /02_February/
# /07_July/
# /11_November/
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /12_December/
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# /12_December/
# /05_May/
# /01_January/
# None
# None
# None
# /11_November/
# /12_December/
# None
# None
# None
# /11_November/
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /08_August/
# /09_September/
# None
# None
# None
# None
# /08_August/
# /10_October/
# None
# /12_December/
# None
# None
# /02_February/
# None
# None
# /06_June/
# None
# None
# /11_November/
# None
# None
# None
# /03_March/
# /06_June/
# None
# None
# None
# None
# /01_January/
# None
# /07_July/
# /07_July/
# None
# None
# None
# None
# None
# None
# /01_January/
# /01_January/
# /10_October/
# None
# None
# /12_December/
# /08_August/
# /01_January/
# /07_July/
# None
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# None
# None
# /02_February/
# None
# /03_March/
# /09_September/
# None
# None
# /02_February/
# /01_January/
# None
# /07_July/
# None
# None
# /05_May/
# /11_November/
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# /01_January/
# /12_December/
# None
# /05_May/
# None
# /07_July/
# /08_August/
# None
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# /05_May/
# /02_February/
# None
# None
# None
# /05_May/
# None
# None
# None
# /09_September/
# None
# None
# /06_June/
# /06_June/
# /07_July/
# None
# None
# /04_April/
# /02_February/
# None
# None
# /01_January/
# /08_August/
# None
# None
# /11_November/
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# /06_June/
# None
# None
# /10_October/
# None
# None
# None
# None
# /06_June/
# /11_November/
# None
# None
# /01_January/
# /02_February/
# /04_April/
# /06_June/
# None
# None
# /09_September/
# /03_March/
# None
# None
# None
# /04_April/
# None
# None
# None
# /05_May/
# None
# /01_January/
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /10_October/
# /11_November/
# None
# None
# /01_January/
# /09_September/
# /12_December/
# None
# None
# None
# None
# /07_July/
# /12_December/
# None
# None
# /04_April/
# None
# /01_January/
# /07_July/
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# /05_May/
# None
# /09_September/
# /09_September/
# None
# None
# None
# /04_April/
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# /09_September/
# None
# None
# None
# None
# /08_August/
# None
# /08_August/
# /10_October/
# None
# None
# None
# /02_February/
# /05_May/
# /07_July/
# None
# None
# /06_June/
# None
# None
# None
# None
# /12_December/
# /10_October/
# None
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# /02_February/
# /04_April/
# /11_November/
# None
# None
# /07_July/
# None
# None
# None
# /08_August/
# None
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# /12_December/
# None
# None
# None
# /05_May/
# None
# None
# /04_April/
# /12_December/
# None
# None
# None
# None
# None
# /01_January/
# /06_June/
# /07_July/
# /04_April/
# /12_December/
# None
# /03_March/
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# /08_August/
# /09_September/
# /09_September/
# None
# /03_March/
# None
# None
# /07_July/
# None
# None
# /04_April/
# /05_May/
# /07_July/
# None
# /01_January/
# /08_August/
# None
# None
# /10_October/
# None
# None
# /06_June/
# None
# None
# None
# /09_September/
# None
# /05_May/
# /05_May/
# None
# /08_August/
# /10_October/
# /02_February/
# /03_March/
# /09_September/
# None
# None
# None
# None
# None
# None
# /06_June/
# /08_August/
# None
# None
# /09_September/
# None
# None
# None
# None
# /03_March/
# None
# /05_May/
# /08_August/
# /02_February/
# None
# None
# /10_October/
# None
# /07_July/
# None
# None
# None
# None
# None
# /01_January/
# /02_February/
# None
# None
# /01_January/
# /03_March/
# /04_April/
# /09_September/
# None
# /10_October/
# /11_November/
# None
# /12_December/
# None
# /05_May/
# /09_September/
# /10_October/
# /10_October/
# None
# None
# None
# None
# None
# None
# /04_April/
# /09_September/
# None
# None
# None
# None
# None
# /03_March/
# /11_November/
# None
# None
# None
# /01_January/
# /03_March/
# None
# None
# None
# None
# None
# /09_September/
# None
# None
# /12_December/
# None
# None
# None
# None
# None
# /01_January/
# None
# None
# None
# None
# None
# None
# None
# None
# /05_May/
# /06_June/
# None
# None
# /05_May/
# /11_November/
# /11_November/
# None
# None
# None
# None
# None
# /11_November/
# None
# None
# /11_November/
# None
# None
# /09_September/
# None
# None
# None
# None
# None
# /04_April/
# /06_June/
# None
# None
# /05_May/
# None
# None
# None
# /07_July/
# None
# None
# None
# None
# /04_April/
# /08_August/
# None
# None
# None
# /02_February/
# /10_October/
# /10_October/
# None
# /06_June/
# None
# None
# None
# None
# None
# None
# /02_February/
# /07_July/
# None
# None
# /11_November/
# None
# /11_November/
# /04_April/
# None
# None
# None
# /03_March/
# /06_June/
# /06_June/
# None
# None
# None
# None
# None
# /02_February/
# /03_March/
# /09_September/
# None
# /08_August/
# /06_June/
# /11_November/
# None
# None
# /11_November/
# /03_March/
# /08_August/
# None
# None
# None
# None
# None
# None
# /03_March/
# /09_September/
# /12_December/
# None
# None
# None
# /07_July/
# None
# /02_February/
# /07_July/
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# /08_August/
# None
# None
# None
# None
# /03_March/
# None
# /03_March/
# None
# /01_January/
# /04_April/
# None
# /01_January/
# /11_November/
# None
# /10_October/
# None
# None
# None
# None
# None
# None
# /02_February/
# /07_July/
# /04_April/
# None
# None
# None
# None
# None
# /05_May/
# None
# None
# None
# None
# None
# None
# None
# /08_August/
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# /02_February/
# /08_August/
# None
# /09_September/
# None
# None
# None
# None
# None
# None
# None
# /02_February/
# /07_July/
# /08_August/
# None
# None
# /05_May/
# /09_September/
# /10_October/
# None
# None
# /01_January/
# None
# None
# None
# None
# /07_July/
# None
# None
# /10_October/
# None
# None
# None
# None
# None
# /07_July/
# /09_September/
# None
# /04_April/
# /08_August/
# /12_December/
# None
# /08_August/
# None
# /06_June/
# /08_August/
# None
# None
# /07_July/
# None
# /05_May/
# None
# None
# /02_February/
# None
# None
# None
# /03_March/
# None
# /01_January/
# /03_March/
# /08_August/
# None
# None
# None
# None
# None
# None
# /07_July/
# None
# None
# /05_May/
# /09_September/
# None
# /12_December/
# None
# None
# /11_November/
# None
# None
# None
# /03_March/
# None
# None
# None
# None
# /11_November/
# None
# None
# /05_May/
# None
# /12_December/
# None
# /10_October/
# None
# None
# None
# None
# None
# None
# None
# None
# /04_April/
# /06_June/
# /11_November/
# None
# None
# None
# None
# None
# /03_March/
# None
# /05_May/
# None
# /01_January/
# None
# None
# None
# /09_September/
# None
# None
# /02_February/
# None
# None
# None
# None
# None
# None
# None
# None
# /07_July/
# /07_July/
# None
# None
# None
# /08_August/
# /03_March/
# /05_May/
# /05_May/
# None
# None
# None
# /09_September/
# None
# /02_February/
# None
# None
# None
# None
# /07_July/
# /10_October/
# /12_December/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /01_January/
# /02_February/
# /03_March/
# /04_April/
# /04_April/
# None
# /08_August/
# None
# None
# /03_March/
# /05_May/
# /11_November/
# None
# None
# /11_November/
# None
# None
# /03_March/
# None
# None
# None
# None
# /01_January/
# /05_May/
# /06_June/
# None
# None
# /02_February/
# None
# /06_June/
# /07_July/
# /09_September/
# None
# None
# /06_June/
# /08_August/
# None
# None
# None

# %%
# Convert timestamp columns (created_at) to datetime format
df['created_at'] = pd.to_datetime(df['created_at'])
print(df['created_at'].dtype)
#Extract additional features from timestamp columns (e.g., year, month, day, hour)
df['year'] = df['created_at'].dt.year
df['month'] = df['created_at'].dt.month
df['day'] = df['created_at'].dt.day
df['hour'] = df['created_at'].dt.hour
#show the first 5 rows of the dataframe
df.head()
# Out:
# datetime64[ns, UTC]
#             author_id                created_at edit_history_tweet_ids  \
# 0            24931983 2019-01-01 23:59:01+00:00    1080252082781855744
# 1          2602968048 2019-01-01 23:57:02+00:00    1080251584729223173
# 2  734730931848634368 2019-01-01 23:55:49+00:00    1080251277693595649
# 3          1242955585 2019-01-01 23:53:00+00:00    1080250568583585792
# 4            18085565 2019-01-01 23:51:36+00:00    1080250217524539393
#
#                                 entities_annotations entities_cashtags  \
# 0  start:30, end:31, probability:0.4413, type:Pla...               :NA
# 1                                               <NA>               :NA
# 2                                               <NA>               :NA
# 3  start:52, end:78, probability:0.4544, type:Oth...               :NA
# 4  start:122, end:127, probability:0.7755, type:P...               :NA
#
#                                    entities_hashtags  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4  start1:184, start2:239, start3:262, end1:196, ...
#
#                                    entities_mentions  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3  start1:82, start2:99, end1:95, end2:109, usern...
# 4  start1:248, start2:275, end1:261, end2:283, us...
#
#                                        entities_urls geo_coord_data  \
# 0  start1:66, start2:90, end1:89, end2:113, url1:...           <NA>
# 1  start:278, end:301, url:https://t.co/is0NHYP90...           <NA>
# 2  start1:55, start2:260, end1:78, end2:283, url1...           <NA>
# 3  start1:140, start2:164, end1:163, end2:187, ur...           <NA>
# 4  start:284, end:307, url:https://t.co/jqCU6Ds5l...           <NA>
#
#   geo_coord_type  ... retweet_count              source  \
# 0           <NA>  ...             0          CoSchedule
# 1           <NA>  ...             0  Twitter Web Client
# 2           <NA>  ...             0    Twitter for iPad
# 3           <NA>  ...             0           TweetDeck
# 4           <NA>  ...             0  Twitter Web Client
#
#                                                 text             tweet_id  \
# 0  Kids Win the Right to Sue the US Government Ov...  1080252082781855744
# 1  Wat zou de eenvoudigste verklaring zijn dat er...  1080251584729223173
# 2  Here's what's on the radar for climate change ...  1080251277693595649
# 3  The biggest story of the year, for all of huma...  1080250568583585792
# 4  Still celebrating 2016 w stale Crystal & ranci...  1080250217524539393
#
#   withheld_copyright  withheld_countrycode  year  month  day hour
# 0               <NA>                  <NA>  2019      1    1   23
# 1               <NA>                  <NA>  2019      1    1   23
# 2               <NA>                  <NA>  2019      1    1   23
# 3               <NA>                  <NA>  2019      1    1   23
# 4               <NA>                  <NA>  2019      1    1   23
#
# [5 rows x 31 columns]

# %% [markdown]
# Plotting the nr of tweets posted over time

# %%
#aggregate tweet counts by day
tweet_counts_by_day = df.resample('D', on='created_at').size()
# Plot time series of tweet volume
plt.figure(figsize=(10, 6))
tweet_counts_by_day.plot(kind='line', color='lightblue')
plt.title('Tweet Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.grid(True)
plt.show()

# %% [markdown]
# Distribution of tweet counts by author: Identify the most active users on the platform.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'author_id' and count the number of tweets for each author
tweet_counts_by_author = df['author_id'].value_counts()

# Get the top 5 most active authors
top_10_authors = tweet_counts_by_author.head(5)

# Calculate the sum of tweets by authors not in the top 5
other_authors_count = tweet_counts_by_author.iloc[5:].sum()

# Combine the top 5 with the 'Other' category
data_for_pie_chart = pd.concat([top_10_authors, pd.Series([other_authors_count], index=['Other'])])

# Define colors for the pie chart
colors = list(plt.get_cmap('tab10').colors) + ['gray']

# Plot the pie chart
plt.figure(figsize=(12, 8))
data_for_pie_chart.plot(
    kind='pie', 
    autopct='%1.1f%%', 
    colors=colors, 
    legend=True
)
plt.title('Tweet Counts by Author (Top 5 + Other)')
plt.ylabel('')  # Remove the y-label for pie chart
plt.show()

# %% [markdown]
# Word Cloud of Most Frequent Hashtags: Popular topic or trends

# %%
from wordcloud import WordCloud

# Extract hashtags from the text of the tweets
hashtags = df['text'].str.findall(r'#(\w+)').explode()

#count the frequency of each hashtag
hashtag_counts = hashtags.value_counts()
#generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(hashtag_counts)
#plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Most Frequent Hashtags')
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# Scatter Plot of Like Count vs. Retweet Count. Identifying tweets that are particularly engaging or viral.

# %%
#extract like count and retweet count data
like_count = df['like_count']
retweet_count = df['retweet_count']

# Plot scatter plot of like count vs. retweet count
plt.figure(figsize=(10, 6))
plt.scatter(like_count, retweet_count, color='blue', alpha=0.5)
plt.title('Like Count vs. Retweet Count')
plt.xlabel('Like Count')
plt.ylabel('Retweet Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Time series of engagement metrics such as like count, retweet count, and reply count

# %%
# Set 'created_at' column as the index
df.set_index('created_at', inplace=True)
# Resample the data to aggregate engagement metrics by day
engagement_metrics_daily = df.resample('D').sum()
#show the first 5 rows of the dataframe
engagement_metrics_daily.head()
# Plot time series of engagement metrics
plt.figure(figsize=(10, 6))
plt.plot(engagement_metrics_daily.index, engagement_metrics_daily['like_count'], label='Like Count', color='blue')
plt.plot(engagement_metrics_daily.index, engagement_metrics_daily['retweet_count'], label='Retweet Count', color='green')
plt.plot(engagement_metrics_daily.index, engagement_metrics_daily['reply_count'], label='Reply Count', color='orange')
plt.title('Time Series of Engagement Metrics')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Distribution of tweet sources to see which platforms are most commonly used for tweeting.

# %%
#count the frequency of each tweet source
tweet_source_counts = df['source'].value_counts()
#plot the 20 most frequent tweet sources
plt.figure(figsize=(12, 6))
tweet_source_counts.head(20).plot(kind='bar', color='lightblue')
plt.title('Tweet Source Counts')
plt.xlabel('Tweet Source')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=45) #rotate x-axis labels for better readability
plt.grid(axis='y') #add grid lines only on the y-axis
plt.show()

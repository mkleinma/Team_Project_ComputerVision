# %%
import h5py
import numpy as np    
import matplotlib.pyplot as plt
import pandas as pd

######## Very basic access to the dataset - let's see what we are working with! #######
raw_dataset = h5py.File('climatevisions_2019.h5','r+') 

# Access the 'upper' data - we only have tweet data 
for item in raw_dataset.keys():
    print("Items: " + item)    
    
# Access the actual subgroups with data for us - different info we can look at - mostly things provided in Excel by Katharina
for item in raw_dataset.require_group('tweet_data').keys():
    continue  ### comment this out if you want to see categories we have and use print
    #print(item)
# Out:
# Items: tweet_data

# %%
# Access the dataset within the group
dataset = raw_dataset['tweet_data']  ## excludes unnecessary information - only tweet_data
 
# Create a dictionary to store column data
data_dict = {}
    
# Iterate through the keys (assuming each key is a column name)
for key in dataset.keys():
     # Access the data for each column
     column_data = dataset[key][:]
        
     # Store the data in the dictionary with the column name as the key
     data_dict[key] = column_data
 
# Convert the dictionary to a Pandas DataFrame
dataFrame = pd.DataFrame(data_dict)
dataFrame.head()
# Out:
#                author_id                   created_at  edit_history_tweet_ids  \
# 0            b'24931983'  b'2019-01-01T23:59:01.000Z'  b'1080252082781855744'
# 1          b'2602968048'  b'2019-01-01T23:57:02.000Z'  b'1080251584729223173'
# 2  b'734730931848634368'  b'2019-01-01T23:55:49.000Z'  b'1080251277693595649'
# 3          b'1242955585'  b'2019-01-01T23:53:00.000Z'  b'1080250568583585792'
# 4            b'18085565'  b'2019-01-01T23:51:36.000Z'  b'1080250217524539393'
#
#                                 entities_annotations entities_cashtags  \
# 0  b'start:30, end:31, probability:0.4413, type:P...            b':NA'
# 1                                              b'NA'            b':NA'
# 2                                              b'NA'            b':NA'
# 3  b'start:52, end:78, probability:0.4544, type:O...            b':NA'
# 4  b'start:122, end:127, probability:0.7755, type...            b':NA'
#
#                                    entities_hashtags  \
# 0                                              b'NA'
# 1                                              b'NA'
# 2                                              b'NA'
# 3                                              b'NA'
# 4  b'start1:184, start2:239, start3:262, end1:196...
#
#                                    entities_mentions  \
# 0                                              b'NA'
# 1                                              b'NA'
# 2                                              b'NA'
# 3  b'start1:82, start2:99, end1:95, end2:109, use...
# 4  b'start1:248, start2:275, end1:261, end2:283, ...
#
#                                        entities_urls geo_coord_data  \
# 0  b'start1:66, start2:90, end1:89, end2:113, url...          b'NA'
# 1  b'start:278, end:301, url:https://t.co/is0NHYP...          b'NA'
# 2  b'start1:55, start2:260, end1:78, end2:283, ur...          b'NA'
# 3  b'start1:140, start2:164, end1:163, end2:187, ...          b'NA'
# 4  b'start:284, end:307, url:https://t.co/jqCU6Ds...          b'NA'
#
#   geo_coord_type  ... possibly_sensitive quote_count referenced_tweets  \
# 0          b'NA'  ...               True           0             b'NA'
# 1          b'NA'  ...               True           0             b'NA'
# 2          b'NA'  ...               True           0             b'NA'
# 3          b'NA'  ...               True           0             b'NA'
# 4          b'NA'  ...               True           0             b'NA'
#
#   reply_count retweet_count                 source  \
# 0           0             0          b'CoSchedule'
# 1           0             0  b'Twitter Web Client'
# 2           0             0    b'Twitter for iPad'
# 3           0             0           b'TweetDeck'
# 4           0             0  b'Twitter Web Client'
#
#                                                 text                tweet_id  \
# 0  b'Kids Win the Right to Sue the US Government ...  b'1080252082781855744'
# 1  b'Wat zou de eenvoudigste verklaring zijn dat ...  b'1080251584729223173'
# 2  b"Here's what's on the radar for climate chang...  b'1080251277693595649'
# 3  b'The biggest story of the year, for all of hu...  b'1080250568583585792'
# 4  b'Still celebrating 2016 w stale Crystal & ran...  b'1080250217524539393'
#
#    withheld_copyright withheld_countrycode
# 0               b'NA'                b'NA'
# 1               b'NA'                b'NA'
# 2               b'NA'                b'NA'
# 3               b'NA'                b'NA'
# 4               b'NA'                b'NA'
#
# [5 rows x 27 columns]

# %%
################## Subset Creation #########################


### How many is up to us, can be tried out based on result of models ###
sorted_tweets = dataFrame.sort_values(by='like_count', ascending=False)

#### Get the top 1000 tweets based on 'like_count' ####
top_1000_tweets = sorted_tweets.head(1000)
top_1000_tweets[['author_id','like_count', 'retweet_count', 'text']] ## different categories 

#### TODO possibly some more
# Out:
#                     author_id  like_count  retweet_count  \
# 392565           b'381268670'       82582          50280
# 446784            b'65497475'       69820          51781
# 230823            b'68820706'       69235          11051
# 589009           b'365956744'       65465           6124
# 147660           b'138203134'       62852           9145
# ...                       ...         ...            ...
# 198774  b'944564902210846720'         631            213
# 615123           b'137295176'         630            244
# 527333          b'3058602759'         629             35
# 96239              b'4898091'         628            247
# 454785            b'23655688'         628            147
#
#                                                      text
# 392565  b'the UN released a 740 page report compiled o...
# 446784  b'The Amazon Rainforest, one of the wettest pl...
# 230823  b'just learned about climate change https://t....
# 589009  b'Climate change caused this. https://t.co/JG2...
# 147660  b'#GreenNewDeal haters\xe2\x80\x99 plan to add...
# ...                                                   ...
# 198774  b'Many children from several schools participa...
# 615123  b'A reminder - the disruption caused by climat...
# 527333  b'An absolute pleasure to have been at Global ...
# 96239   b"Meet Greta Thunberg, a 16-year-old in Sweden...
# 454785  b'Is it immoral to have babies in the era of c...
#
# [1000 rows x 4 columns]

# %%
### print some tweets out of interest
tweetPrintCount = 0
for item in sorted_tweets:
    if tweetPrintCount < 50:
        top_tweet = sorted_tweets.iloc[tweetPrintCount]
        print(top_tweet['text'])
        tweetPrintCount += 1
# Out:
# b'the UN released a 740 page report compiled over six years by 250 scientists from 70 nations that basically states that unless drastic measures are taken to combat climate change, we are looking at mass extinction by 2050. At this point I don\xe2\x80\x99t know if having kids is even ethical https://t.co/CsdTSpfRPv'
# b'The Amazon Rainforest, one of the wettest places on Earth, is on fire.  Siberia, one of the coldest places on Earth, is on fire.That aint normal. Climate change is for real and our planet is burning up. Humans are the cause of this deadly fever.#PrayforAmazonia https://t.co/D6VCTaCNXt'
# b'just learned about climate change https://t.co/OlmKwz2bOn'
# b'Climate change caused this. https://t.co/JG2LyeX8Tx'
# b'#GreenNewDeal haters\xe2\x80\x99 plan to address Climate Change: https://t.co/ahuDXnxcDG'
# b'Jon Snow, a tired millennial, dealing with wild political instability, accelerating climate change, and all the bullshit that his parents\xe2\x80\x99 generation created and refused to deal with responsibly. #GameofThrones https://t.co/icETZh6oPH'
# b'Iceland just held a funeral for its first ever glacier lost to climate change. https://t.co/VmuXbLH0pV https://t.co/CCdASlreMo'
# b'My TL going from James Charles to abortion laws to climate change and pollution to dog videos https://t.co/zjKNhYN5BA'
# b"The Amazon rainforest has been burning for 3 weeks! We are on the verge of losing it completely if the fire isn't put out. The loss of trees, the loss of biodiversity is what is accelerating CLIMATE CHANGE. THIS IS AN INTERNATIONAL EMERGENCY. This is a CRISIS.#SaveTheAmazon https://t.co/EDx1bub5AZ"
# b"From nurseries to full forest areas, the success of Billion Tree Tsunami has been unprecedented with public & pvt involvement. Has given us confidence to take the initiative to 10 bn trees. KP's forest cover has increased by 4%, contributing to the fight against climate change https://t.co/xFqJpwUq0u"
